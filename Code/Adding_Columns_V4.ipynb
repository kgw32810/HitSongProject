# %% [markdown]
# Import libraries needed and get/clean dataset

# %%
import pandas as pd
import requests
import json
import time
import re #regular expressions
from concurrent.futures import ThreadPoolExecutor, as_completed
import unicodedata
import os

# %%
# Load the CSV file, specifying the semicolon delimiter
file_path = 'BaseDataset.csv'
df = pd.read_csv(file_path,encoding="utf-8")
df.head(5)

#clean table: if track name contains "(feat. %)" or "(with %)" then remove that text from the song title 
#using regular expressions and making sure its not case sensitive
df['track_name'] = df['track_name'].replace(r'(?i)\s*\(feat\.?[^)]*\)','', regex=True)
df['track_name'] = df['track_name'].replace(r'(?i)\s*\(with\.?[^)]*\)','', regex=True)

#fix utf-8 text issue i am seeing in the dataset. (special characters like apostrophe look to be encoded as cp1252.)
def fix_text(text):
    if isinstance(text, str):
        try:
            return text.encode('cp1252', errors='replace').decode('utf-8', errors='replace')
        except UnicodeDecodeError:
            #wasn't working before when I tried to 
            return text.encode('cp1252', errors='replace').decode('utf-8', errors='ignore')
    return text

#to match hot100, it doesnt have the spanish alphabet characters. the code below should normalize the song titles to match the database
def remove_accents(text):
    text = str(text) #some songs are numbers (:
    # Normalize the text to decompose accented characters
    normalized_text = unicodedata.normalize('NFKD', text)
    # Remove the combining characters (accents) by filtering them out
    return "".join(c for c in normalized_text if not unicodedata.combining(c))

df['track_name'] = df['track_name'].apply(fix_text)
df['artists'] = df['artists'].apply(fix_text)

df['track_name'] = df['track_name'].str.replace("’", "'", regex=False)
df['artists'] = df['artists'].str.replace("’", "'", regex=False)

df['track_name'] = df['track_name'].apply(remove_accents)
df['artists'] = df['artists'].apply(remove_accents)
# Out:
# C:\Users\Destiny\AppData\Local\Temp\ipykernel_21844\1423931418.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#    Unnamed: 0                track_id                 artists  \
# 0           0                     NaN             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms explicit  danceability  \
# 0                      Comedy          73       230666    False         0.676
# 1            Ghost - Acoustic          55       149610      NaN         0.420
# 2              To Begin Again          57       210826    False         0.438
# 3  Can't Help Falling In Love          71       201933    False         0.266
# 4                     Hold On          82       198853    False         0.618
#
#    energy  ...  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  0.4610  ...    -6.746     0       0.1430        0.0322          0.000001
# 1  0.1660  ...   -17.235     1       0.0763        0.9240          0.000006
# 2  0.3590  ...    -9.734     1       0.0557        0.2100          0.000000
# 3  0.0596  ...   -18.515     1       0.0363        0.9050          0.000071
# 4  0.4430  ...    -9.681     1       0.0526        0.4690          0.000000
#
#    liveness  valence    tempo  time_signature  track_genre
# 0    0.3580    0.715   87.917               4     acoustic
# 1    0.1010    0.267   77.489               4     acoustic
# 2    0.1170    0.120   76.332               4     acoustic
# 3    0.1320    0.143  181.740               3     acoustic
# 4    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %% [markdown]
# Build Artist level dataset
#
# - Call on API from The Audio DB to gain more information about the artist
# - Use API to get Artist level instagram following information

# %%
'''
--------------------------------------
CREATE ARTIST DATAFRAME
--------------------------------------

Each row in our dataset is a song. The column Artists contains multiple artists who worked on a song. The code below will
split up the Artists (delimited by a semi-colan) and create a new dataframe that contains only unique artists.

This will be built up to create an artist level table, where we will add any additional characteristics about the artist that
could help predict song popularity.
'''
df_split = df['artists'].str.split(';', expand=True)
df_split.columns = [f'artist_{i+1}' for i in range(df_split.shape[1])]
df_final = pd.concat([df, df_split], axis=1)

unique_artists = df['artists'].str.split(';', expand=True).stack().unique()
unique_artists_df = pd.DataFrame(unique_artists, columns=['artists'])

# %%
'''
--------------------------------------
EDIT ORIGINAL DATASET TO BE AT SONG/ARTIST LEVEL
--------------------------------------
'''
# Ensure the 'artists' column is string type
df['artists'] = df['artists'].astype(str)

# Split the 'artists' column into lists where necessary
df['artists'] = df['artists'].apply(lambda x: x.split(';') if ';' in x else [x])

# Explode the 'artists' column to create one row per artist
df_exploded = df.explode('artists').reset_index(drop=True)

# Strip any leading/trailing whitespace from artist names
df_exploded['artists'] = df_exploded['artists'].str.strip()

print(df_exploded.head())
# Out:
#    Unnamed: 0                track_id            artists  \
# 0           0                     NaN        Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A       Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson
# 3           2  1iJBSr7s7jYXzM8EGcbK5b               ZAYN
# 4           3  6lfxq3CG4xtTiEg7opyCyx       Kina Grannis
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3                                     To Begin Again
# 4  Crazy Rich Asians (Original Motion Picture Sou...
#
#                    track_name  popularity  duration_ms explicit  danceability  \
# 0                      Comedy          73       230666    False         0.676
# 1            Ghost - Acoustic          55       149610      NaN         0.420
# 2              To Begin Again          57       210826    False         0.438
# 3              To Begin Again          57       210826    False         0.438
# 4  Can't Help Falling In Love          71       201933    False         0.266
#
#    energy  ...  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  0.4610  ...    -6.746     0       0.1430        0.0322          0.000001
# 1  0.1660  ...   -17.235     1       0.0763        0.9240          0.000006
# 2  0.3590  ...    -9.734     1       0.0557        0.2100          0.000000
# 3  0.3590  ...    -9.734     1       0.0557        0.2100          0.000000
# 4  0.0596  ...   -18.515     1       0.0363        0.9050          0.000071
#
#    liveness  valence    tempo  time_signature  track_genre
# 0     0.358    0.715   87.917               4     acoustic
# 1     0.101    0.267   77.489               4     acoustic
# 2     0.117    0.120   76.332               4     acoustic
# 3     0.117    0.120   76.332               4     acoustic
# 4     0.132    0.143  181.740               3     acoustic
#
# [5 rows x 21 columns]

# %%
'''
---------------------------------
Create the below API call functions: 

API CALL 1: ARTIST ID FROM ARTIST NAME

API CALL 2: ARTIST DETAILS FROM ARTIST ID

API CALL 3: ARTIST SOCIAL MEDIA DATA FROM ARTIST ID
---------------------------------

Obtain Additional artist level data using The AudioDB 

NOTE: The API_KEY below will no longer be active. It was received from paying for a membership to The AudioDB which has since been cancelled.

'''

API_KEY = '523532'

#API CALL 1: Get Artist AudioDB ID using their name
def get_artist_info(artist_name):
    url = f"https://www.theaudiodb.com/api/v1/json/{API_KEY}/search.php?s={artist_name}"
    try:
        retry_count = 0
        while retry_count <10 :
            response = requests.get(url, timeout=10)
            if response.status_code == 200:
                data = response.json()
                if 'artists' in data and data['artists'] is not None:
                    artist = data['artists'][0]
                    return artist.get('idArtist', 'N/A'), artist.get('strLabel', 'N/A')
                else:
                    #If response was successful but artist doesnt exist
                    return 'N/A','N/A'
            else:
                #If I get an error code
                print(f"Status Code: {response.status_code}")
                print(f"Response Headers: {response.headers}")
                data = response.json()
                print("Raw JSON Data:", data)
                retry_count+=1
                time.sleep(1)
    except Exception as e:
        print(f"Error fetching data for {artist_name}: {e}")
    return 'N/A', 'N/A'

#API CALL 2: Get Artist details by their AudioDB ID
def get_artist_details(artist_id):
    url = f"https://www.theaudiodb.com/api/v1/json/{API_KEY}/artist.php?i={artist_id}"
    try:
        retry_count = 0
        while retry_count <10 :
            response = requests.get(url, timeout=10)
            if response.status_code == 200:
                data = response.json()
                if 'artists' in data and data['artists'] is not None:
                    artist = data['artists'][0]
                    return(
                        artist.get('strStyle', 'N/A'),
                        artist.get('strGenre', 'N/A'),
                        artist.get('strMood', 'N/A'),
                        artist.get('strFacebook', 'N/A'),
                        artist.get('strTwitter', 'N/A'),
                        artist.get('strGender', 'N/A'),
                        artist.get('strMusicBrainzID', 'N/A'),
                        artist.get('strLastFMChart', 'N/A')
                    )
                else:
                    #If response was successful but artist doesnt exist
                    return ('N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A')
            else:
                #If I get an error code
                print(f"Status Code: {response.status_code}")
                print(f"Response Headers: {response.headers}")
                data = response.json()
                print("Raw JSON Data:", data)
                retry_count+=1
                time.sleep(1)
    except Exception as e:
        print(f"Error fetching data for {artist_id}: {e}")
    return ('N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A')

#API CALL 3: Social media data:
def get_artist_socials(artist_id): 
    url = f"https://www.theaudiodb.com/api/v1/json/{API_KEY}/artist-links.php?i={artist_id}"
    
    #only want to pull info for these social medias:
    social_media = {
        'facebook': '',
        'twitter': '',
        'spotify': '',
        'deezer': '',
        'itunes': '',
        'tidal': '',
        'youtube': '',
        'instagram': ''
    }
    
    try:
        retry_count = 0
        while retry_count <10 :
            response = requests.get(url, timeout=10)
            #print(f"Received response. Status code: {response.status_code}") 

            if response.status_code == 200:
                data = response.json()
                #print(f"JSON data received: {data}")  # Debug print

                if 'artists' in data and data['artists'] is not None:
                    for link in data['artists']:
                        if link['strSite'] in social_media:
                            social_media[link['strSite']] = link['strLink']
                    return(social_media)
                else:
                    print(f"No social media data found for artist ID:  {artist_id}")
                    return (social_media)
            else:
                #If I get an error code
                print(f"Status Code: {response.status_code}")
                print(f"Response Headers: {response.headers}")
                data = response.json()
                print("Raw JSON Data:", data)
                retry_count+=1
                time.sleep(1)
    except Exception as e:
        print(f"Error fetching data for {artist_id}: {e}")
        
    #print(f"Returning social media data: {social_media}")  # Debug print
    return(social_media)

# %%
'''
CALL API CALL FUNCTION 1 FROM ABOVE AND SAVE ARTIST LEVEL DATA

NOTE: This will not work without updating the API_KEY
'''

#Create two new columns to the artist data table
unique_artists_df['artist_id'] = [None] * len(unique_artists_df)
unique_artists_df['record_label'] = [None] * len(unique_artists_df)

# Apply the function to get data for two new columns
for index in range(len(unique_artists_df)):
    myartist = unique_artists_df['artists'][index]
    #print("processing:",myartist)
    callresponse = get_artist_info(myartist)
    unique_artists_df['artist_id'][index] = callresponse[0]
    unique_artists_df['record_label'][index] = callresponse[1]
    # Add a 1-second delay between API calls
    #time.sleep(1)

# %%
'''
CALL API FUNCTION 2 FROM ABOVE AND SAVE ARTIST LEVEL DATA

NOTE: This will not work without updating the API_KEY
'''

unique_artists_details = unique_artists_df.copy()

#filter for only those with an audioDB id (to reduce run-time of the API call, we don't want to call on artists we know won't be in the database)
unique_artists_details = unique_artists_details[unique_artists_details['artist_id']!='N/A']

# Add new columns for the API results
unique_artists_details['strStyle'] = 'N/A'
unique_artists_details['strGenre'] = 'N/A'
unique_artists_details['strMood'] = 'N/A'
unique_artists_details['strFacebook'] = 'N/A'
unique_artists_details['strTwitter'] = 'N/A'
unique_artists_details['strGender'] = 'N/A'
unique_artists_details['strMusicBrainzID'] = 'N/A'
unique_artists_details['strLastFMChart'] = 'N/A'

# Apply the function to create two new columns
for index, row in unique_artists_details.iterrows():
    artist_id = row['artist_id']
    callresponse = get_artist_details(artist_id)
    
    # Update the DataFrame with API results
    unique_artists_details.at[index, 'strStyle'] = callresponse[0]
    unique_artists_details.at[index, 'strGenre'] = callresponse[1]
    unique_artists_details.at[index, 'strMood'] = callresponse[2]
    unique_artists_details.at[index, 'strFacebook'] = callresponse[3]
    unique_artists_details.at[index, 'strTwitter'] = callresponse[4]
    unique_artists_details.at[index, 'strGender'] = callresponse[5]
    unique_artists_details.at[index, 'strMusicBrainzID'] = callresponse[6]
    unique_artists_details.at[index, 'strLastFMChart'] = callresponse[7]

# Display the updated DataFrame & check we have all data
#print(len(unique_artists_details))
print(unique_artists_details.head(5))
# Out:
#              artists artist_id record_label          strStyle strGenre  \
# 2  Ingrid Michaelson    120114         None              Folk    Indie
# 3               ZAYN    141655     Columbia          Rock/Pop      Pop
# 4       Kina Grannis    111830         None          Rock/Pop      Pop
# 6       Tyrone Wells    147082         None              None     Folk
# 7  A Great Big World    126846         Epic  Manufactured Pop      Pop
#
#         strMood                     strFacebook strTwitter strGender  \
# 2                                                        1    Female
# 3  Good Natured               facebook.com/zayn          1      Male
# 4                en-gb.facebook.com/kinagrannis          1    Female
# 6          None                            None       None      None
# 7         Happy                                          1      Male
#
#                        strMusicBrainzID  \
# 2  1fc494a1-9109-4081-a455-2d05bea9d2bf
# 3  985f7e6f-0a7e-4de7-b9ec-a5dac63cb2f7
# 4  7a1766ba-3d50-428f-b6f5-4d267248c744
# 6  d576231e-c0b6-4a42-a4f4-011f06b9095c
# 7  6958e806-1e14-4844-a0a7-07a27756aa0f
#
#                                       strLastFMChart
# 2                                               None
# 3                                               None
# 4  http://www.last.fm/music/Kina Grannis/+charts?...
# 6                                               None
# 7                                               None

# %%
'''
CALL API FUNCTION 3 ABOVE: Get artist social media data and add it to artist table

NOTE: This will not work without updating the API_KEY
'''

# Add new columns for the API results
unique_artists_details['twitter_link'] = [None] * len(unique_artists_details)
unique_artists_details['spotify_link'] = [None] * len(unique_artists_details)
unique_artists_details['deezer_link']  = [None] * len(unique_artists_details)
unique_artists_details['itunes_link']  = [None] * len(unique_artists_details)
unique_artists_details['tidal_link']   = [None] * len(unique_artists_details)
unique_artists_details['youtube_link'] = [None] * len(unique_artists_details)
unique_artists_details['instagram_link'] = [None] * len(unique_artists_details)


# Apply the function to create two new columns
for index, row in unique_artists_details.iterrows():

    artist_id = row['artist_id']
    callresponse = get_artist_socials(artist_id) #this is a dictionary now

# 2  open.spotify.com/artist/2vm8GdHyrJh2O2MfbQFYG0
# 3  open.spotify.com/artist/5ZsFI1h6hIdQRw2ti0hz81
# 4  open.spotify.com/artist/7h4j9YTJJuAHzLCc3KCvYu
# 6
# 7  open.spotify.com/artist/5xKp3UyavIBUsGy3DQdXeF
#
#                      deezer_link                             itunes_link  \
# 2    www.deezer.com/artist/16797  itunes.apple.com/us/artist/id157692029
# 3  www.deezer.com/artist/9761322  itunes.apple.com/gb/artist/id973181994
# 4   www.deezer.com/artist/405995     itunes.apple.com/artist/id415821967
# 6
# 7  www.deezer.com/artist/4043368  itunes.apple.com/us/artist/id569333045
#
#                         tidal_link  \
# 2    listen.tidal.com/artist/62450
# 3
# 4  listen.tidal.com/artist/3894285
# 6
# 7
#
#                                        youtube_link  \
# 2             www.youtube.com/user/IngridMichaelson
# 3  www.youtube.com/channel/UC3PdiRW5dUA4V70ueeR1eHA
# 4                  www.youtube.com/user/kinagrannis
# 6
# 7               www.youtube.com/user/AGreatBigWorld
#
#                         instagram_link                      facebook_link
# 2  www.instagram.com/ingridmichaelson/  www.facebook.com/ingridmichaelson
# 3              www.instagram.com/zayn/                  facebook.com/zayn
# 4       www.instagram.com/kinagrannis/     en-gb.facebook.com/kinagrannis
# 6
# 7    www.instagram.com/agreatbigworld/    www.facebook.com/agreatbigworld

# %%
'''
---------------------------------
Instagram follower API
---------------------------------
'''

def normalize_instagram_url(url):
    """
    Normalize Instagram URLs to ensure consistent matching
    - Remove protocol (http:// or https://)
    - Remove www. 
    - Remove trailing slashes
    - Convert to lowercase
    """
    if pd.isna(url):
        return ''
    
    # Ensure url is a string
    url = str(url)
    
    # Remove protocol
    url = re.sub(r'^https?://', '', url)
    
    # Remove www.
    url = re.sub(r'^www\.', '', url)
    
    # Remove trailing slash
    url = url.rstrip('/')
    
    # Convert to lowercase
    url = url.lower()
    
    return url

def merge_followers_count(db1_path, db2_path, output_path):
    try:
        # Read the CSV files
        db1 = pd.read_csv(db1_path, low_memory=False)
        db2 = pd.read_csv(db2_path, low_memory=False)
        
        # Normalize Instagram URLs in both dataframes
        db1['normalized_instagram_link'] = db1['instagram_link'].apply(normalize_instagram_url)
        db2['normalized_userUrl'] = db2['userUrl'].apply(normalize_instagram_url)
        
        # Print some debugging information
        print("Sample normalized links in DB1:")
        print(db1[['instagram_link', 'normalized_instagram_link']].head())
        
        print("\nSample normalized links in DB2:")
        print(db2[['userUrl', 'normalized_userUrl']].head())
        
        # Create a copy of db1
        merged_db = db1.copy()
        
        # Create a new column for followers count
        merged_db['instagram_followers_count'] = ''
        
        # Create a dictionary to map normalized Instagram URLs to followers count
        followers_dict = dict(zip(db2['normalized_userUrl'], db2['followersCount']))
        
        # Debugging: Print dictionary size and some entries
        print(f"\nTotal unique normalized URLs in followers dictionary: {len(followers_dict)}")
        print("Sample dictionary entries:")
        for k, v in list(followers_dict.items())[:5]:
            print(f"{k}: {v}")
        
        # Counters for tracking matches
        total_urls = 0
        matched_urls = 0
        
        # Iterate through the rows and update followers count
        for index, row in merged_db.iterrows():
            # Get the normalized Instagram link
            normalized_link = row['normalized_instagram_link']
            
            # Skip if no link
            if not normalized_link:
                continue
            
            total_urls += 1
            
            # Try to find a match in the followers dictionary
            followers_count = followers_dict.get(normalized_link, '')
            
            if followers_count:
                matched_urls += 1
                merged_db.at[index, 'instagram_followers_count'] = followers_count
        
        # Print matching statistics
        print(f"\nTotal Instagram URLs processed: {total_urls}")
        print(f"Matched URLs: {matched_urls}")
        print(f"Matching percentage: {matched_urls/total_urls*100:.2f}%")
        
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        merged_db.to_csv(output_path, index=False)
        
        print(f"\nMerged database saved to {output_path}")
        
        return merged_db
    
    except Exception as e:
        print(f"An error occurred: {e}")
        import traceback
        traceback.print_exc()
        return None

if __name__ == "__main__":
    merged_result = merge_followers_count(
        r'original_db_additional_columns(in).csv',
        r'insta_followers.csv',
        r'A:\new DB\merged_database.csv'
    )

# %% [markdown]
# Build Song level data
# - Use The Audio DB API
# - Check if the song has trended on the app TikTok

# %%
'''
---------------------------------
Joining initial Spotify and Tiktok datasets

---------------------------------
'''
def join_spotify_tiktok_datasets(spotify_file_path, tiktok_file_path, output_file_path=None):
    """
    Join Spotify and TikTok datasets based on track_id.
    
    Parameters:
    -----------
    spotify_file_path : str
        Path to the Spotify dataset CSV file
    tiktok_file_path : str
        Path to the TikTok dataset CSV file
    output_file_path : str, optional
        Path to save the joined dataset. If None, the function will return the DataFrame
        
    Returns:
    --------
    pd.DataFrame
        The joined dataset if output_file_path is None, otherwise None
    """
    # Load the datasets
    print(f"Loading Spotify dataset from {spotify_file_path}...")
    spotify_df = pd.read_csv(spotify_file_path)
    
    print(f"Loading TikTok dataset from {tiktok_file_path}...")
    tiktok_df = pd.read_csv(tiktok_file_path)
    
    # Clean up the datasets
    if '' in spotify_df.columns:
        spotify_df = spotify_df.drop('', axis=1)
    
    # Rename columns to avoid conflicts and clearly identify the source
    common_columns = set(spotify_df.columns).intersection(set(tiktok_df.columns))
    common_columns.discard('track_id')  # Keep track_id unchanged as it's our join key
    
    # Rename common columns in TikTok dataset
    rename_dict = {col: f'tiktok_{col}' for col in common_columns}
    tiktok_df = tiktok_df.rename(columns=rename_dict)
    
    # Rename common columns in Spotify dataset
    rename_dict = {col: f'spotify_{col}' for col in common_columns}
    spotify_df = spotify_df.rename(columns=rename_dict)
    
    # Handle missing track_ids (if any)
    spotify_df = spotify_df.dropna(subset=['track_id'])
    tiktok_df = tiktok_df.dropna(subset=['track_id'])
    
    # Perform the join
    print("Joining datasets on track_id...")
    joined_df = pd.merge(
        spotify_df, 
        tiktok_df, 
        on='track_id', 
        how='outer',  
        indicator=True  
    )
    
    # Print some info about the join
    merge_counts = joined_df['_merge'].value_counts()
    print("\nJoin Results:")
    print(f"Total rows in joined dataset: {len(joined_df)}")
    print(f"Rows only in Spotify: {merge_counts.get('left_only', 0)}")
    print(f"Rows only in TikTok: {merge_counts.get('right_only', 0)}")
    print(f"Rows in both datasets: {merge_counts.get('both', 0)}")
    
    # Save to file if output path is provided
    if output_file_path:
        print(f"Saving joined dataset to {output_file_path}...")
        joined_df.to_csv(output_file_path, index=False)
        print("Done!")
        return None
    
    return joined_df

if __name__ == "__main__":
    # Update these paths to match your file locations
    spotify_path = "Spotify Datasetin.csv"
    tiktok_path = "tiktok.csv"
    output_path = "joined_spotify_tiktok.csv"
    
    join_spotify_tiktok_datasets(spotify_path, tiktok_path, output_path)

# %%
'''
---------------------------------
Create the below API call function to get TRACK/SONG level data: 

API CALL 1: TRACK INFO FROM ARTIST NAME & TRACK NAME

'''
def get_track_details(artist_name, track_name):
    url = f"https://www.theaudiodb.com/api/v1/json/{API_KEY}/searchtrack.php?s={artist_name}&t={track_name}"
    try:
        retry_count = 0
        while retry_count <10 :
            response = requests.get(url, timeout=10)
            if response.status_code == 200:
                data = response.json()
                if 'track' in data and data['track'] is not None:
                    track = data['track'][0]
                    return(
                        track.get('idTrack', 'N/A'),
                        track.get('strTheme', 'N/A'),
                        track.get('strMusicVid', 'N/A'),
                        track.get('intMusicVidViews', 'N/A'),
                        track.get('intMusicVidLikes', 'N/A'),
                        track.get('intMusicVidDislikes', 'N/A'),
                        track.get('intMusicVidComments', 'N/A'),
                        track.get('intTotalListeners', 'N/A'),
                        track.get('intTotalPlays', 'N/A'),
                        track.get('strMusicBrainzID', 'N/A') #probably dont need but just in case
                    )
                else:
                    #If response was successful but artist doesnt exist
                    # return ('N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A')
                    return (None, None, None, None, None, None, None, None, None, None)
            else:
                #If I get an error code
                print(f"Status Code: {response.status_code}")
                print(f"Response Headers: {response.headers}")
                data = response.json()
                print("Raw JSON Data:", data)
                retry_count+=1
                time.sleep(1)
    except Exception as e:
        print(f"Error fetching data for {artist_name} and {track_name}: {e}")
    # return ('N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A')
    return (None, None, None, None, None, None, None, None, None, None)

# %%
'''This code chunk was optimized to run faster in the chunk below'''

# '''Add Track level data'''

# #Create new columns to the artist data table
# df_exploded['idTrack']      = [None] * len(df_exploded)
# df_exploded['strTheme']     = [None] * len(df_exploded)
# df_exploded['strMusicVid']  = [None] * len(df_exploded)
# df_exploded['intMusicVidViews']  = [None] * len(df_exploded)
# df_exploded['intMusicVidLikes']  = [None] * len(df_exploded)
# df_exploded['intMusicVidDislikes'] = [None] * len(df_exploded)
# df_exploded['intMusicVidComments'] = [None] * len(df_exploded)
# df_exploded['intTotalListeners']   = [None] * len(df_exploded)
# df_exploded['intTotalPlays'] = [None] * len(df_exploded)
# df_exploded['strMusicBrainzID'] = [None] * len(df_exploded)

# # Apply the function to get data for two new columns
# for index, row in df_exploded.iterrows():
#     artistname = df_exploded['artists'][index]
#     trackname = df_exploded['track_name'][index]

#     #print("processing:",artistname,",",trackname)
#     if index % 1000 == 0:
#         print(f"Reached the {index}th iteration")
#     callresponse = get_track_details(artistname, trackname)
#     df_exploded.loc[index, 'idTrack']        = callresponse[0]
#     df_exploded.loc[index, 'strTheme']       = callresponse[1]
#     df_exploded.loc[index, 'strMusicVid']    = callresponse[2]
#     df_exploded.loc[index, 'intMusicVidViews']    = callresponse[3]
#     df_exploded.loc[index, 'intMusicVidLikes']    = callresponse[4]
#     df_exploded.loc[index, 'intMusicVidDislikes'] = callresponse[5]
#     df_exploded.loc[index, 'intMusicVidComments'] = callresponse[6]
#     df_exploded.loc[index, 'intTotalListeners']   = callresponse[7]
#     df_exploded.loc[index, 'intTotalPlays']       = callresponse[8]
#     df_exploded.loc[index, 'strMusicBrainzID']    = callresponse[9]

#     # Add a 1-second delay between API calls
#     #time.sleep(1)
# Out:
# 'This code chunk was optimized to run faster in the chunk below'

# %%
'''Add Track Level Data'''
#same as above code chunk. Just updated to run faster (SRC: https://www.digitalocean.com/community/tutorials/how-to-use-threadpoolexecutor-in-python-3)

# Add new columns
columns_to_add = [
    'idTrack', 'strTheme', 'strMusicVid', 'intMusicVidViews', 'intMusicVidLikes',
    'intMusicVidDislikes', 'intMusicVidComments', 'intTotalListeners',
    'intTotalPlays', 'strMusicBrainzID'
]
for col in columns_to_add:
    df_exploded[col] = None

# Function wrapper to include index for mapping back
def fetch_track_data(index, artistname, trackname):
    try:
        result = get_track_details(artistname, trackname)
        return index, result
    except Exception as e:
        print(f"Error at index {index}: {e}")
        return index, [None] * 10  # output if error

# Prepare input list
inputs = [(index, row['artists'], row['track_name']) for index, row in df_exploded.iterrows()]

# Run in batches of 10
batch_size = 10
for i in range(0, len(inputs), batch_size):

    print(f"Processing batch {i} to {i+batch_size}")
    batch = inputs[i:i + batch_size]

    with ThreadPoolExecutor(max_workers=batch_size) as executor:
        futures = [executor.submit(fetch_track_data, *args) for args in batch]

        for future in as_completed(futures):
            index, data = future.result()
            if data:
                for col, value in zip(columns_to_add, data):
                    df_exploded.at[index, col] = value
# Out:
# Processing batch 0 to 10
# Processing batch 10 to 20
# Processing batch 20 to 30
# Processing batch 30 to 40
# Processing batch 40 to 50
# Processing batch 50 to 60
# Processing batch 60 to 70
# Processing batch 70 to 80
# Processing batch 80 to 90
# Processing batch 90 to 100
# Processing batch 100 to 110
# Processing batch 110 to 120
# Processing batch 120 to 130
# Processing batch 130 to 140
# Processing batch 140 to 150
# Processing batch 150 to 160
# Processing batch 160 to 170
# Processing batch 170 to 180
# Processing batch 180 to 190
# Processing batch 190 to 200
# Processing batch 200 to 210
# Processing batch 210 to 220
# Processing batch 220 to 230
# Processing batch 230 to 240
# Processing batch 240 to 250
# Processing batch 250 to 260
# Processing batch 260 to 270
# Processing batch 270 to 280
# Processing batch 280 to 290
# Processing batch 290 to 300
# Processing batch 300 to 310
# Processing batch 310 to 320
# Processing batch 320 to 330
# Processing batch 330 to 340
# Processing batch 340 to 350
# Processing batch 350 to 360
# Processing batch 360 to 370
# Processing batch 370 to 380
# Processing batch 380 to 390
# Processing batch 390 to 400
# Processing batch 400 to 410
# Processing batch 410 to 420
# Processing batch 420 to 430
# Processing batch 430 to 440
# Processing batch 440 to 450
# Processing batch 450 to 460
# Processing batch 460 to 470
# Processing batch 470 to 480
# Processing batch 480 to 490
# Processing batch 490 to 500
# Processing batch 500 to 510
# Processing batch 510 to 520
# Processing batch 520 to 530
# Processing batch 530 to 540
# Processing batch 540 to 550
# Processing batch 550 to 560
# Processing batch 560 to 570
# Processing batch 570 to 580
# Processing batch 580 to 590
# Processing batch 590 to 600
# Processing batch 600 to 610
# Processing batch 610 to 620
# Processing batch 620 to 630
# Processing batch 630 to 640
# Processing batch 640 to 650
# Processing batch 650 to 660
# Processing batch 660 to 670
# Processing batch 670 to 680
# Processing batch 680 to 690
# Processing batch 690 to 700
# Processing batch 700 to 710
# Processing batch 710 to 720
# Processing batch 720 to 730
# Processing batch 730 to 740
# Processing batch 740 to 750
# Processing batch 750 to 760
# Processing batch 760 to 770
# Processing batch 770 to 780
# Processing batch 780 to 790
# Processing batch 790 to 800
# Processing batch 800 to 810
# Processing batch 810 to 820
# Processing batch 820 to 830
# Processing batch 830 to 840
# Processing batch 840 to 850
# Processing batch 850 to 860
# Processing batch 860 to 870
# Processing batch 870 to 880
# Processing batch 880 to 890
# Processing batch 890 to 900
# Processing batch 900 to 910
# Processing batch 910 to 920
# Processing batch 920 to 930
# Processing batch 930 to 940
# Processing batch 940 to 950
# Processing batch 950 to 960
# Processing batch 960 to 970
# Processing batch 970 to 980
# Processing batch 980 to 990
# Processing batch 990 to 1000
# Processing batch 1000 to 1010
# Processing batch 1010 to 1020
# Processing batch 1020 to 1030
# Processing batch 1030 to 1040
# Processing batch 1040 to 1050
# Processing batch 1050 to 1060
# Processing batch 1060 to 1070
# Processing batch 1070 to 1080
# Processing batch 1080 to 1090
# Processing batch 1090 to 1100
# Processing batch 1100 to 1110
# Processing batch 1110 to 1120
# Processing batch 1120 to 1130
# Processing batch 1130 to 1140
# Processing batch 1140 to 1150
# Processing batch 1150 to 1160
# Processing batch 1160 to 1170
# Processing batch 1170 to 1180
# Processing batch 1180 to 1190
# Processing batch 1190 to 1200
# Processing batch 1200 to 1210
# Processing batch 1210 to 1220
# Processing batch 1220 to 1230
# Processing batch 1230 to 1240
# Processing batch 1240 to 1250
# Processing batch 1250 to 1260
# Processing batch 1260 to 1270
# Processing batch 1270 to 1280
# Processing batch 1280 to 1290
# Processing batch 1290 to 1300
# Processing batch 1300 to 1310
# Processing batch 1310 to 1320
# Processing batch 1320 to 1330
# Processing batch 1330 to 1340
# Processing batch 1340 to 1350
# Processing batch 1350 to 1360
# Processing batch 1360 to 1370
# Processing batch 1370 to 1380
# Processing batch 1380 to 1390
# Processing batch 1390 to 1400
# Processing batch 1400 to 1410
# Processing batch 1410 to 1420
# Processing batch 1420 to 1430
# Processing batch 1430 to 1440
# Processing batch 1440 to 1450
# Processing batch 1450 to 1460
# Processing batch 1460 to 1470
# Processing batch 1470 to 1480
# Processing batch 1480 to 1490
# Processing batch 1490 to 1500
# Processing batch 1500 to 1510
# Processing batch 1510 to 1520
# Processing batch 1520 to 1530
# Processing batch 1530 to 1540
# Processing batch 1540 to 1550
# Processing batch 1550 to 1560
# Processing batch 1560 to 1570
# Processing batch 1570 to 1580
# Processing batch 1580 to 1590
# Processing batch 1590 to 1600
# Processing batch 1600 to 1610
# Processing batch 1610 to 1620
# Processing batch 1620 to 1630
# Processing batch 1630 to 1640
# Processing batch 1640 to 1650
# Processing batch 1650 to 1660
# Processing batch 1660 to 1670
# Processing batch 1670 to 1680
# Processing batch 1680 to 1690
# Processing batch 1690 to 1700
# Processing batch 1700 to 1710
# Processing batch 1710 to 1720
# Processing batch 1720 to 1730
# Processing batch 1730 to 1740
# Processing batch 1740 to 1750
# Processing batch 1750 to 1760
# Processing batch 1760 to 1770
# Processing batch 1770 to 1780
# Processing batch 1780 to 1790
# Processing batch 1790 to 1800
# Processing batch 1800 to 1810
# Processing batch 1810 to 1820
# Processing batch 1820 to 1830
# Processing batch 1830 to 1840
# Processing batch 1840 to 1850
# Processing batch 1850 to 1860
# Processing batch 1860 to 1870
# Processing batch 1870 to 1880
# Processing batch 1880 to 1890
# Processing batch 1890 to 1900
# Processing batch 1900 to 1910
# Processing batch 1910 to 1920
# Processing batch 1920 to 1930
# Processing batch 1930 to 1940
# Processing batch 1940 to 1950
# Processing batch 1950 to 1960
# Processing batch 1960 to 1970
# Processing batch 1970 to 1980
# Processing batch 1980 to 1990
# Processing batch 1990 to 2000
# Processing batch 2000 to 2010
# Processing batch 2010 to 2020
# Processing batch 2020 to 2030
# Processing batch 2030 to 2040
# Processing batch 2040 to 2050
# Processing batch 2050 to 2060
# Processing batch 2060 to 2070
# Processing batch 2070 to 2080
# Processing batch 2080 to 2090
# Processing batch 2090 to 2100
# Processing batch 2100 to 2110
# Processing batch 2110 to 2120
# Processing batch 2120 to 2130
# Processing batch 2130 to 2140
# Processing batch 2140 to 2150
# Processing batch 2150 to 2160
# Processing batch 2160 to 2170
# Processing batch 2170 to 2180
# Processing batch 2180 to 2190
# Processing batch 2190 to 2200
# Processing batch 2200 to 2210
# Processing batch 2210 to 2220
# Processing batch 2220 to 2230
# Processing batch 2230 to 2240
# Processing batch 2240 to 2250
# Processing batch 2250 to 2260
# Processing batch 2260 to 2270
# Processing batch 2270 to 2280
# Processing batch 2280 to 2290
# Processing batch 2290 to 2300
# Processing batch 2300 to 2310
# Processing batch 2310 to 2320
# Processing batch 2320 to 2330
# Processing batch 2330 to 2340
# Processing batch 2340 to 2350
# Processing batch 2350 to 2360
# Processing batch 2360 to 2370
# Processing batch 2370 to 2380
# Processing batch 2380 to 2390
# Processing batch 2390 to 2400
# Processing batch 2400 to 2410
# Processing batch 2410 to 2420
# Processing batch 2420 to 2430
# Processing batch 2430 to 2440
# Processing batch 2440 to 2450
# Processing batch 2450 to 2460
# Processing batch 2460 to 2470
# Processing batch 2470 to 2480
# Processing batch 2480 to 2490
# Processing batch 2490 to 2500
# Processing batch 2500 to 2510
# Processing batch 2510 to 2520
# Processing batch 2520 to 2530
# Processing batch 2530 to 2540
# Processing batch 2540 to 2550
# Processing batch 2550 to 2560
# Processing batch 2560 to 2570
# Processing batch 2570 to 2580
# Processing batch 2580 to 2590
# Processing batch 2590 to 2600
# Processing batch 2600 to 2610
# Processing batch 2610 to 2620
# Processing batch 2620 to 2630
# Processing batch 2630 to 2640
# Processing batch 2640 to 2650
# Processing batch 2650 to 2660
# Processing batch 2660 to 2670
# Processing batch 2670 to 2680
# Processing batch 2680 to 2690
# Processing batch 2690 to 2700
# Processing batch 2700 to 2710
# Processing batch 2710 to 2720
# Processing batch 2720 to 2730
# Processing batch 2730 to 2740
# Processing batch 2740 to 2750
# Processing batch 2750 to 2760
# Processing batch 2760 to 2770
# Processing batch 2770 to 2780
# Processing batch 2780 to 2790
# Processing batch 2790 to 2800
# Processing batch 2800 to 2810
# Processing batch 2810 to 2820
# Processing batch 2820 to 2830
# Processing batch 2830 to 2840
# Processing batch 2840 to 2850
# Processing batch 2850 to 2860
# Processing batch 2860 to 2870
# Processing batch 2870 to 2880
# Processing batch 2880 to 2890
# Processing batch 2890 to 2900
# Processing batch 2900 to 2910
# Processing batch 2910 to 2920
# Processing batch 2920 to 2930
# Processing batch 2930 to 2940
# Processing batch 2940 to 2950
# Processing batch 2950 to 2960
# Processing batch 2960 to 2970
# Processing batch 2970 to 2980
# Processing batch 2980 to 2990
# Processing batch 2990 to 3000
# Processing batch 3000 to 3010
# Processing batch 3010 to 3020
# Processing batch 3020 to 3030
# Processing batch 3030 to 3040
# Processing batch 3040 to 3050
# Processing batch 3050 to 3060
# Processing batch 3060 to 3070
# Processing batch 3070 to 3080
# Processing batch 3080 to 3090
# Processing batch 3090 to 3100
# Processing batch 3100 to 3110
# Processing batch 3110 to 3120
# Processing batch 3120 to 3130
# Processing batch 3130 to 3140
# Processing batch 3140 to 3150
# Processing batch 3150 to 3160
# Processing batch 3160 to 3170
# Processing batch 3170 to 3180
# Processing batch 3180 to 3190
# Processing batch 3190 to 3200
# Processing batch 3200 to 3210
# Processing batch 3210 to 3220
# Processing batch 3220 to 3230
# Processing batch 3230 to 3240
# Processing batch 3240 to 3250
# Processing batch 3250 to 3260
# Processing batch 3260 to 3270
# Processing batch 3270 to 3280
# Processing batch 3280 to 3290
# Processing batch 3290 to 3300
# Processing batch 3300 to 3310
# Processing batch 3310 to 3320
# Processing batch 3320 to 3330
# Processing batch 3330 to 3340
# Processing batch 3340 to 3350
# Processing batch 3350 to 3360
# Processing batch 3360 to 3370
# Processing batch 3370 to 3380
# Processing batch 3380 to 3390
# Processing batch 3390 to 3400
# Processing batch 3400 to 3410
# Processing batch 3410 to 3420
# Processing batch 3420 to 3430
# Processing batch 3430 to 3440
# Processing batch 3440 to 3450
# Processing batch 3450 to 3460
# Processing batch 3460 to 3470
# Processing batch 3470 to 3480
# Processing batch 3480 to 3490
# Processing batch 3490 to 3500
# Processing batch 3500 to 3510
# Processing batch 3510 to 3520
# Processing batch 3520 to 3530
# Processing batch 3530 to 3540
# Processing batch 3540 to 3550
# Processing batch 3550 to 3560
# Processing batch 3560 to 3570
# Processing batch 3570 to 3580
# Processing batch 3580 to 3590
# Processing batch 3590 to 3600
# Processing batch 3600 to 3610
# Processing batch 3610 to 3620
# Processing batch 3620 to 3630
# Processing batch 3630 to 3640
# Processing batch 3640 to 3650
# Processing batch 3650 to 3660
# Processing batch 3660 to 3670
# Processing batch 3670 to 3680
# Processing batch 3680 to 3690
# Processing batch 3690 to 3700
# Processing batch 3700 to 3710
# Processing batch 3710 to 3720
# Processing batch 3720 to 3730
# Processing batch 3730 to 3740
# Processing batch 3740 to 3750
# Processing batch 3750 to 3760
# Processing batch 3760 to 3770
# Processing batch 3770 to 3780
# Processing batch 3780 to 3790
# Processing batch 3790 to 3800
# Processing batch 3800 to 3810
# Processing batch 3810 to 3820
# Processing batch 3820 to 3830
# Processing batch 3830 to 3840
# Processing batch 3840 to 3850
# Processing batch 3850 to 3860
# Processing batch 3860 to 3870
# Processing batch 3870 to 3880
# Processing batch 3880 to 3890
# Processing batch 3890 to 3900
# Processing batch 3900 to 3910
# Processing batch 3910 to 3920
# Processing batch 3920 to 3930
# Processing batch 3930 to 3940
# Processing batch 3940 to 3950
# Processing batch 3950 to 3960
# Processing batch 3960 to 3970
# Processing batch 3970 to 3980
# Processing batch 3980 to 3990
# Processing batch 3990 to 4000
# Processing batch 4000 to 4010
# Processing batch 4010 to 4020
# Processing batch 4020 to 4030
# Processing batch 4030 to 4040
# Processing batch 4040 to 4050
# Processing batch 4050 to 4060
# Processing batch 4060 to 4070
# Processing batch 4070 to 4080
# Processing batch 4080 to 4090
# Processing batch 4090 to 4100
# Processing batch 4100 to 4110
# Processing batch 4110 to 4120
# Processing batch 4120 to 4130
# Processing batch 4130 to 4140
# Processing batch 4140 to 4150
# Processing batch 4150 to 4160
# Processing batch 4160 to 4170
# Processing batch 4170 to 4180
# Processing batch 4180 to 4190
# Processing batch 4190 to 4200
# Processing batch 4200 to 4210
# Processing batch 4210 to 4220
# Processing batch 4220 to 4230
# Processing batch 4230 to 4240
# Processing batch 4240 to 4250
# Processing batch 4250 to 4260
# Processing batch 4260 to 4270
# Processing batch 4270 to 4280
# Processing batch 4280 to 4290
# Processing batch 4290 to 4300
# Processing batch 4300 to 4310
# Processing batch 4310 to 4320
# Processing batch 4320 to 4330
# Processing batch 4330 to 4340
# Processing batch 4340 to 4350
# Processing batch 4350 to 4360
# Processing batch 4360 to 4370
# Processing batch 4370 to 4380
# Processing batch 4380 to 4390
# Processing batch 4390 to 4400
# Processing batch 4400 to 4410
# Processing batch 4410 to 4420
# Processing batch 4420 to 4430
# Processing batch 4430 to 4440
# Processing batch 4440 to 4450
# Processing batch 4450 to 4460
# Processing batch 4460 to 4470
# Processing batch 4470 to 4480
# Processing batch 4480 to 4490
# Processing batch 4490 to 4500
# Processing batch 4500 to 4510
# Processing batch 4510 to 4520
# Processing batch 4520 to 4530
# Processing batch 4530 to 4540
# Processing batch 4540 to 4550
# Processing batch 4550 to 4560
# Processing batch 4560 to 4570
# Processing batch 4570 to 4580
# Processing batch 4580 to 4590
# Processing batch 4590 to 4600
# Processing batch 4600 to 4610
# Processing batch 4610 to 4620
# Processing batch 4620 to 4630
# Processing batch 4630 to 4640
# Processing batch 4640 to 4650
# Processing batch 4650 to 4660
# Processing batch 4660 to 4670
# Processing batch 4670 to 4680
# Processing batch 4680 to 4690
# Processing batch 4690 to 4700
# Processing batch 4700 to 4710
# Processing batch 4710 to 4720
# Processing batch 4720 to 4730
# Processing batch 4730 to 4740
# Processing batch 4740 to 4750
# Processing batch 4750 to 4760
# Processing batch 4760 to 4770
# Processing batch 4770 to 4780
# Processing batch 4780 to 4790
# Processing batch 4790 to 4800
# Processing batch 4800 to 4810
# Processing batch 4810 to 4820
# Processing batch 4820 to 4830
# Processing batch 4830 to 4840
# Processing batch 4840 to 4850
# Processing batch 4850 to 4860
# Processing batch 4860 to 4870
# Processing batch 4870 to 4880
# Processing batch 4880 to 4890
# Processing batch 4890 to 4900
# Processing batch 4900 to 4910
# Processing batch 4910 to 4920
# Processing batch 4920 to 4930
# Processing batch 4930 to 4940
# Processing batch 4940 to 4950
# Processing batch 4950 to 4960
# Processing batch 4960 to 4970
# Processing batch 4970 to 4980
# Processing batch 4980 to 4990
# Processing batch 4990 to 5000
# Processing batch 5000 to 5010
# Processing batch 5010 to 5020
# Processing batch 5020 to 5030
# Processing batch 5030 to 5040
# Processing batch 5040 to 5050
# Processing batch 5050 to 5060
# Processing batch 5060 to 5070
# Processing batch 5070 to 5080
# Processing batch 5080 to 5090
# Processing batch 5090 to 5100
# Processing batch 5100 to 5110
# Processing batch 5110 to 5120
# Processing batch 5120 to 5130
# Processing batch 5130 to 5140
# Processing batch 5140 to 5150
# Processing batch 5150 to 5160
# Processing batch 5160 to 5170
# Processing batch 5170 to 5180
# Processing batch 5180 to 5190
# Processing batch 5190 to 5200
# Processing batch 5200 to 5210
# Processing batch 5210 to 5220
# Processing batch 5220 to 5230
# Processing batch 5230 to 5240
# Processing batch 5240 to 5250
# Processing batch 5250 to 5260
# Processing batch 5260 to 5270
# Processing batch 5270 to 5280
# Processing batch 5280 to 5290
# Processing batch 5290 to 5300
# Processing batch 5300 to 5310
# Processing batch 5310 to 5320
# Processing batch 5320 to 5330
# Processing batch 5330 to 5340
# Processing batch 5340 to 5350
# Processing batch 5350 to 5360
# Processing batch 5360 to 5370
# Processing batch 5370 to 5380
# Processing batch 5380 to 5390
# Processing batch 5390 to 5400
# Processing batch 5400 to 5410
# Processing batch 5410 to 5420
# Processing batch 5420 to 5430
# Processing batch 5430 to 5440
# Processing batch 5440 to 5450
# Processing batch 5450 to 5460
# Processing batch 5460 to 5470
# Processing batch 5470 to 5480
# Processing batch 5480 to 5490
# Processing batch 5490 to 5500
# Processing batch 5500 to 5510
# Processing batch 5510 to 5520
# Processing batch 5520 to 5530
# Processing batch 5530 to 5540
# Processing batch 5540 to 5550
# Processing batch 5550 to 5560
# Processing batch 5560 to 5570
# Processing batch 5570 to 5580
# Processing batch 5580 to 5590
# Processing batch 5590 to 5600
# Processing batch 5600 to 5610
# Processing batch 5610 to 5620
# Processing batch 5620 to 5630
# Processing batch 5630 to 5640
# Processing batch 5640 to 5650
# Processing batch 5650 to 5660
# Processing batch 5660 to 5670
# Processing batch 5670 to 5680
# Processing batch 5680 to 5690
# Processing batch 5690 to 5700
# Processing batch 5700 to 5710
# Processing batch 5710 to 5720
# Processing batch 5720 to 5730
# Processing batch 5730 to 5740
# Processing batch 5740 to 5750
# Processing batch 5750 to 5760
# Processing batch 5760 to 5770
# Processing batch 5770 to 5780
# Processing batch 5780 to 5790
# Processing batch 5790 to 5800
# Processing batch 5800 to 5810
# Processing batch 5810 to 5820
# Processing batch 5820 to 5830
# Processing batch 5830 to 5840
# Processing batch 5840 to 5850
# Processing batch 5850 to 5860
# Processing batch 5860 to 5870
# Processing batch 5870 to 5880
# Processing batch 5880 to 5890
# Processing batch 5890 to 5900
# Processing batch 5900 to 5910
# Processing batch 5910 to 5920
# Processing batch 5920 to 5930
# Processing batch 5930 to 5940
# Processing batch 5940 to 5950
# Processing batch 5950 to 5960
# Processing batch 5960 to 5970
# Processing batch 5970 to 5980
# Processing batch 5980 to 5990
# Processing batch 5990 to 6000
# Processing batch 6000 to 6010
# Processing batch 6010 to 6020
# Processing batch 6020 to 6030
# Processing batch 6030 to 6040
# Processing batch 6040 to 6050
# Processing batch 6050 to 6060
# Processing batch 6060 to 6070
# Processing batch 6070 to 6080
# Processing batch 6080 to 6090
# Processing batch 6090 to 6100
# Processing batch 6100 to 6110
# Processing batch 6110 to 6120
# Processing batch 6120 to 6130
# Processing batch 6130 to 6140
# Processing batch 6140 to 6150
# Processing batch 6150 to 6160
# Processing batch 6160 to 6170
# Processing batch 6170 to 6180
# Processing batch 6180 to 6190
# Processing batch 6190 to 6200
# Processing batch 6200 to 6210
# Processing batch 6210 to 6220
# Processing batch 6220 to 6230
# Processing batch 6230 to 6240
# Processing batch 6240 to 6250
# Processing batch 6250 to 6260
# Processing batch 6260 to 6270
# Processing batch 6270 to 6280
# Processing batch 6280 to 6290
# Processing batch 6290 to 6300
# Processing batch 6300 to 6310
# Processing batch 6310 to 6320
# Processing batch 6320 to 6330
# Processing batch 6330 to 6340
# Processing batch 6340 to 6350
# Processing batch 6350 to 6360
# Processing batch 6360 to 6370
# Processing batch 6370 to 6380
# Processing batch 6380 to 6390
# Processing batch 6390 to 6400
# Processing batch 6400 to 6410
# Processing batch 6410 to 6420
# Processing batch 6420 to 6430
# Processing batch 6430 to 6440
# Processing batch 6440 to 6450
# Processing batch 6450 to 6460
# Processing batch 6460 to 6470
# Processing batch 6470 to 6480
# Processing batch 6480 to 6490
# Processing batch 6490 to 6500
# Processing batch 6500 to 6510
# Processing batch 6510 to 6520
# Processing batch 6520 to 6530
# Processing batch 6530 to 6540
# Processing batch 6540 to 6550
# Processing batch 6550 to 6560
# Processing batch 6560 to 6570
# Processing batch 6570 to 6580
# Processing batch 6580 to 6590
# Processing batch 6590 to 6600
# Processing batch 6600 to 6610
# Processing batch 6610 to 6620
# Processing batch 6620 to 6630
# Processing batch 6630 to 6640
# Processing batch 6640 to 6650
# Processing batch 6650 to 6660
# Processing batch 6660 to 6670
# Processing batch 6670 to 6680
# Processing batch 6680 to 6690
# Processing batch 6690 to 6700
# Processing batch 6700 to 6710
# Processing batch 6710 to 6720
# Processing batch 6720 to 6730
# Processing batch 6730 to 6740
# Processing batch 6740 to 6750
# Processing batch 6750 to 6760
# Processing batch 6760 to 6770
# Processing batch 6770 to 6780
# Processing batch 6780 to 6790
# Processing batch 6790 to 6800
# Processing batch 6800 to 6810
# Processing batch 6810 to 6820
# Processing batch 6820 to 6830
# Processing batch 6830 to 6840
# Processing batch 6840 to 6850
# Processing batch 6850 to 6860
# Processing batch 6860 to 6870
# Processing batch 6870 to 6880
# Processing batch 6880 to 6890
# Processing batch 6890 to 6900
# Processing batch 6900 to 6910
# Processing batch 6910 to 6920
# Processing batch 6920 to 6930
# Processing batch 6930 to 6940
# Processing batch 6940 to 6950
# Processing batch 6950 to 6960
# Processing batch 6960 to 6970
# Processing batch 6970 to 6980
# Processing batch 6980 to 6990
# Processing batch 6990 to 7000
# Processing batch 7000 to 7010
# Processing batch 7010 to 7020
# Processing batch 7020 to 7030
# Processing batch 7030 to 7040
# Processing batch 7040 to 7050
# Processing batch 7050 to 7060
# Processing batch 7060 to 7070
# Processing batch 7070 to 7080
# Processing batch 7080 to 7090
# Processing batch 7090 to 7100
# Processing batch 7100 to 7110
# Processing batch 7110 to 7120
# Processing batch 7120 to 7130
# Processing batch 7130 to 7140
# Processing batch 7140 to 7150
# Processing batch 7150 to 7160
# Processing batch 7160 to 7170
# Processing batch 7170 to 7180
# Processing batch 7180 to 7190
# Processing batch 7190 to 7200
# Processing batch 7200 to 7210
# Processing batch 7210 to 7220
# Processing batch 7220 to 7230
# Processing batch 7230 to 7240
# Processing batch 7240 to 7250
# Processing batch 7250 to 7260
# Processing batch 7260 to 7270
# Processing batch 7270 to 7280
# Processing batch 7280 to 7290
# Processing batch 7290 to 7300
# Processing batch 7300 to 7310
# Processing batch 7310 to 7320
# Processing batch 7320 to 7330
# Processing batch 7330 to 7340
# Processing batch 7340 to 7350
# Processing batch 7350 to 7360
# Processing batch 7360 to 7370
# Processing batch 7370 to 7380
# Processing batch 7380 to 7390
# Processing batch 7390 to 7400
# Processing batch 7400 to 7410
# Processing batch 7410 to 7420
# Processing batch 7420 to 7430
# Processing batch 7430 to 7440
# Processing batch 7440 to 7450
# Processing batch 7450 to 7460
# Processing batch 7460 to 7470
# Processing batch 7470 to 7480
# Processing batch 7480 to 7490
# Processing batch 7490 to 7500
# Processing batch 7500 to 7510
# Processing batch 7510 to 7520
# Processing batch 7520 to 7530
# Processing batch 7530 to 7540
# Processing batch 7540 to 7550
# Processing batch 7550 to 7560
# Processing batch 7560 to 7570
# Processing batch 7570 to 7580
# Processing batch 7580 to 7590
# Processing batch 7590 to 7600
# Processing batch 7600 to 7610
# Processing batch 7610 to 7620
# Processing batch 7620 to 7630
# Processing batch 7630 to 7640
# Processing batch 7640 to 7650
# Processing batch 7650 to 7660
# Processing batch 7660 to 7670
# Processing batch 7670 to 7680
# Processing batch 7680 to 7690
# Processing batch 7690 to 7700
# Processing batch 7700 to 7710
# Processing batch 7710 to 7720
# Processing batch 7720 to 7730
# Processing batch 7730 to 7740
# Processing batch 7740 to 7750
# Processing batch 7750 to 7760
# Processing batch 7760 to 7770
# Processing batch 7770 to 7780
# Processing batch 7780 to 7790
# Processing batch 7790 to 7800
# Processing batch 7800 to 7810
# Processing batch 7810 to 7820
# Processing batch 7820 to 7830
# Processing batch 7830 to 7840
# Processing batch 7840 to 7850
# Processing batch 7850 to 7860
# Processing batch 7860 to 7870
# Processing batch 7870 to 7880
# Processing batch 7880 to 7890
# Processing batch 7890 to 7900
# Processing batch 7900 to 7910
# Processing batch 7910 to 7920
# Processing batch 7920 to 7930
# Processing batch 7930 to 7940
# Processing batch 7940 to 7950
# Processing batch 7950 to 7960
# Processing batch 7960 to 7970
# Processing batch 7970 to 7980
# Processing batch 7980 to 7990
# Processing batch 7990 to 8000
# Processing batch 8000 to 8010
# Processing batch 8010 to 8020
# Processing batch 8020 to 8030
# Processing batch 8030 to 8040
# Processing batch 8040 to 8050
# Processing batch 8050 to 8060
# Processing batch 8060 to 8070
# Processing batch 8070 to 8080
# Processing batch 8080 to 8090
# Processing batch 8090 to 8100
# Processing batch 8100 to 8110
# Processing batch 8110 to 8120
# Processing batch 8120 to 8130
# Processing batch 8130 to 8140
# Processing batch 8140 to 8150
# Processing batch 8150 to 8160
# Processing batch 8160 to 8170
# Processing batch 8170 to 8180
# Processing batch 8180 to 8190
# Processing batch 8190 to 8200
# Processing batch 8200 to 8210
# Processing batch 8210 to 8220
# Processing batch 8220 to 8230
# Processing batch 8230 to 8240
# Processing batch 8240 to 8250
# Processing batch 8250 to 8260
# Processing batch 8260 to 8270
# Processing batch 8270 to 8280
# Processing batch 8280 to 8290
# Processing batch 8290 to 8300
# Processing batch 8300 to 8310
# Processing batch 8310 to 8320
# Processing batch 8320 to 8330
# Processing batch 8330 to 8340
# Processing batch 8340 to 8350
# Processing batch 8350 to 8360
# Processing batch 8360 to 8370
# Processing batch 8370 to 8380
# Processing batch 8380 to 8390
# Processing batch 8390 to 8400
# Processing batch 8400 to 8410
# Processing batch 8410 to 8420
# Processing batch 8420 to 8430
# Processing batch 8430 to 8440
# Processing batch 8440 to 8450
# Processing batch 8450 to 8460
# Processing batch 8460 to 8470
# Processing batch 8470 to 8480
# Processing batch 8480 to 8490
# Processing batch 8490 to 8500
# Processing batch 8500 to 8510
# Processing batch 8510 to 8520
# Processing batch 8520 to 8530
# Processing batch 8530 to 8540
# Processing batch 8540 to 8550
# Processing batch 8550 to 8560
# Processing batch 8560 to 8570
# Processing batch 8570 to 8580
# Processing batch 8580 to 8590
# Processing batch 8590 to 8600
# Processing batch 8600 to 8610
# Processing batch 8610 to 8620
# Processing batch 8620 to 8630
# Processing batch 8630 to 8640
# Processing batch 8640 to 8650
# Processing batch 8650 to 8660
# Processing batch 8660 to 8670
# Processing batch 8670 to 8680
# Processing batch 8680 to 8690
# Processing batch 8690 to 8700
# Processing batch 8700 to 8710
# Processing batch 8710 to 8720
# Processing batch 8720 to 8730
# Processing batch 8730 to 8740
# Processing batch 8740 to 8750
# Processing batch 8750 to 8760
# Processing batch 8760 to 8770
# Processing batch 8770 to 8780
# Processing batch 8780 to 8790
# Processing batch 8790 to 8800
# Processing batch 8800 to 8810
# Processing batch 8810 to 8820
# Processing batch 8820 to 8830
# Processing batch 8830 to 8840
# Processing batch 8840 to 8850
# Processing batch 8850 to 8860
# Processing batch 8860 to 8870
# Processing batch 8870 to 8880
# Processing batch 8880 to 8890
# Processing batch 8890 to 8900
# Processing batch 8900 to 8910
# Processing batch 8910 to 8920
# Processing batch 8920 to 8930
# Processing batch 8930 to 8940
# Processing batch 8940 to 8950
# Processing batch 8950 to 8960
# Processing batch 8960 to 8970
# Processing batch 8970 to 8980
# Processing batch 8980 to 8990
# Processing batch 8990 to 9000
# Processing batch 9000 to 9010
# Processing batch 9010 to 9020
# Processing batch 9020 to 9030
# Processing batch 9030 to 9040
# Processing batch 9040 to 9050
# Processing batch 9050 to 9060
# Processing batch 9060 to 9070
# Processing batch 9070 to 9080
# Processing batch 9080 to 9090
# Processing batch 9090 to 9100
# Processing batch 9100 to 9110
# Processing batch 9110 to 9120
# Processing batch 9120 to 9130
# Processing batch 9130 to 9140
# Processing batch 9140 to 9150
# Processing batch 9150 to 9160
# Processing batch 9160 to 9170
# Processing batch 9170 to 9180
# Processing batch 9180 to 9190
# Processing batch 9190 to 9200
# Processing batch 9200 to 9210
# Processing batch 9210 to 9220
# Processing batch 9220 to 9230
# Processing batch 9230 to 9240
# Processing batch 9240 to 9250
# Processing batch 9250 to 9260
# Processing batch 9260 to 9270
# Processing batch 9270 to 9280
# Processing batch 9280 to 9290
# Processing batch 9290 to 9300
# Processing batch 9300 to 9310
# Processing batch 9310 to 9320
# Processing batch 9320 to 9330
# Processing batch 9330 to 9340
# Processing batch 9340 to 9350
# Processing batch 9350 to 9360
# Processing batch 9360 to 9370
# Processing batch 9370 to 9380
# Processing batch 9380 to 9390
# Processing batch 9390 to 9400
# Processing batch 9400 to 9410
# Processing batch 9410 to 9420
# Processing batch 9420 to 9430
# Processing batch 9430 to 9440
# Processing batch 9440 to 9450
# Processing batch 9450 to 9460
# Processing batch 9460 to 9470
# Processing batch 9470 to 9480
# Processing batch 9480 to 9490
# Processing batch 9490 to 9500
# Processing batch 9500 to 9510
# Processing batch 9510 to 9520
# Processing batch 9520 to 9530
# Processing batch 9530 to 9540
# Processing batch 9540 to 9550
# Processing batch 9550 to 9560
# Processing batch 9560 to 9570
# Processing batch 9570 to 9580
# Processing batch 9580 to 9590
# Processing batch 9590 to 9600
# Processing batch 9600 to 9610
# Processing batch 9610 to 9620
# Processing batch 9620 to 9630
# Processing batch 9630 to 9640
# Processing batch 9640 to 9650
# Processing batch 9650 to 9660
# Processing batch 9660 to 9670
# Processing batch 9670 to 9680
# Processing batch 9680 to 9690
# Processing batch 9690 to 9700
# Processing batch 9700 to 9710
# Processing batch 9710 to 9720
# Processing batch 9720 to 9730
# Processing batch 9730 to 9740
# Processing batch 9740 to 9750
# Processing batch 9750 to 9760
# Processing batch 9760 to 9770
# Processing batch 9770 to 9780
# Processing batch 9780 to 9790
# Processing batch 9790 to 9800
# Processing batch 9800 to 9810
# Processing batch 9810 to 9820
# Processing batch 9820 to 9830
# Processing batch 9830 to 9840
# Processing batch 9840 to 9850
# Processing batch 9850 to 9860
# Processing batch 9860 to 9870
# Processing batch 9870 to 9880
# Processing batch 9880 to 9890
# Processing batch 9890 to 9900
# Processing batch 9900 to 9910
# Processing batch 9910 to 9920
# Processing batch 9920 to 9930
# Processing batch 9930 to 9940
# Processing batch 9940 to 9950
# Processing batch 9950 to 9960
# Processing batch 9960 to 9970
# Processing batch 9970 to 9980
# Processing batch 9980 to 9990
# Processing batch 9990 to 10000
# Processing batch 10000 to 10010
# Processing batch 10010 to 10020
# Processing batch 10020 to 10030
# Processing batch 10030 to 10040
# Processing batch 10040 to 10050
# Processing batch 10050 to 10060
# Processing batch 10060 to 10070
# Processing batch 10070 to 10080
# Processing batch 10080 to 10090
# Processing batch 10090 to 10100
# Processing batch 10100 to 10110
# Processing batch 10110 to 10120
# Processing batch 10120 to 10130
# Processing batch 10130 to 10140
# Processing batch 10140 to 10150
# Processing batch 10150 to 10160
# Processing batch 10160 to 10170
# Processing batch 10170 to 10180
# Processing batch 10180 to 10190
# Processing batch 10190 to 10200
# Processing batch 10200 to 10210
# Processing batch 10210 to 10220
# Processing batch 10220 to 10230
# Processing batch 10230 to 10240
# Processing batch 10240 to 10250
# Processing batch 10250 to 10260
# Processing batch 10260 to 10270
# Processing batch 10270 to 10280
# Processing batch 10280 to 10290
# Processing batch 10290 to 10300
# Processing batch 10300 to 10310
# Processing batch 10310 to 10320
# Processing batch 10320 to 10330
# Processing batch 10330 to 10340
# Processing batch 10340 to 10350
# Processing batch 10350 to 10360
# Processing batch 10360 to 10370
# Processing batch 10370 to 10380
# Processing batch 10380 to 10390
# Processing batch 10390 to 10400
# Processing batch 10400 to 10410
# Processing batch 10410 to 10420
# Processing batch 10420 to 10430
# Processing batch 10430 to 10440
# Processing batch 10440 to 10450
# Processing batch 10450 to 10460
# Processing batch 10460 to 10470
# Processing batch 10470 to 10480
# Processing batch 10480 to 10490
# Processing batch 10490 to 10500
# Processing batch 10500 to 10510
# Processing batch 10510 to 10520
# Processing batch 10520 to 10530
# Processing batch 10530 to 10540
# Processing batch 10540 to 10550
# Processing batch 10550 to 10560
# Processing batch 10560 to 10570
# Processing batch 10570 to 10580
# Processing batch 10580 to 10590
# Processing batch 10590 to 10600
# Processing batch 10600 to 10610
# Processing batch 10610 to 10620
# Processing batch 10620 to 10630
# Processing batch 10630 to 10640
# Processing batch 10640 to 10650
# Processing batch 10650 to 10660
# Processing batch 10660 to 10670
# Processing batch 10670 to 10680
# Processing batch 10680 to 10690
# Processing batch 10690 to 10700
# Processing batch 10700 to 10710
# Processing batch 10710 to 10720
# Processing batch 10720 to 10730
# Processing batch 10730 to 10740
# Processing batch 10740 to 10750
# Processing batch 10750 to 10760
# Processing batch 10760 to 10770
# Processing batch 10770 to 10780
# Processing batch 10780 to 10790
# Processing batch 10790 to 10800
# Processing batch 10800 to 10810
# Processing batch 10810 to 10820
# Processing batch 10820 to 10830
# Processing batch 10830 to 10840
# Processing batch 10840 to 10850
# Processing batch 10850 to 10860
# Processing batch 10860 to 10870
# Processing batch 10870 to 10880
# Processing batch 10880 to 10890
# Processing batch 10890 to 10900
# Processing batch 10900 to 10910
# Processing batch 10910 to 10920
# Processing batch 10920 to 10930
# Processing batch 10930 to 10940
# Processing batch 10940 to 10950
# Processing batch 10950 to 10960
# Processing batch 10960 to 10970
# Processing batch 10970 to 10980
# Processing batch 10980 to 10990
# Processing batch 10990 to 11000
# Processing batch 11000 to 11010
# Processing batch 11010 to 11020
# Processing batch 11020 to 11030
# Processing batch 11030 to 11040
# Processing batch 11040 to 11050
# Processing batch 11050 to 11060
# Processing batch 11060 to 11070
# Processing batch 11070 to 11080
# Processing batch 11080 to 11090
# Processing batch 11090 to 11100
# Processing batch 11100 to 11110
# Processing batch 11110 to 11120
# Processing batch 11120 to 11130
# Processing batch 11130 to 11140
# Processing batch 11140 to 11150
# Processing batch 11150 to 11160
# Processing batch 11160 to 11170
# Processing batch 11170 to 11180
# Processing batch 11180 to 11190
# Processing batch 11190 to 11200
# Processing batch 11200 to 11210
# Processing batch 11210 to 11220
# Processing batch 11220 to 11230
# Processing batch 11230 to 11240
# Processing batch 11240 to 11250
# Processing batch 11250 to 11260
# Processing batch 11260 to 11270
# Processing batch 11270 to 11280
# Processing batch 11280 to 11290
# Processing batch 11290 to 11300
# Processing batch 11300 to 11310
# Processing batch 11310 to 11320
# Processing batch 11320 to 11330
# Processing batch 11330 to 11340
# Processing batch 11340 to 11350
# Processing batch 11350 to 11360
# Processing batch 11360 to 11370
# Processing batch 11370 to 11380
# Processing batch 11380 to 11390
# Processing batch 11390 to 11400
# Processing batch 11400 to 11410
# Processing batch 11410 to 11420
# Processing batch 11420 to 11430
# Processing batch 11430 to 11440
# Processing batch 11440 to 11450
# Processing batch 11450 to 11460
# Processing batch 11460 to 11470
# Processing batch 11470 to 11480
# Processing batch 11480 to 11490
# Processing batch 11490 to 11500
# Processing batch 11500 to 11510
# Processing batch 11510 to 11520
# Processing batch 11520 to 11530
# Processing batch 11530 to 11540
# Processing batch 11540 to 11550
# Processing batch 11550 to 11560
# Processing batch 11560 to 11570
# Processing batch 11570 to 11580
# Processing batch 11580 to 11590
# Processing batch 11590 to 11600
# Processing batch 11600 to 11610
# Processing batch 11610 to 11620
# Processing batch 11620 to 11630
# Processing batch 11630 to 11640
# Processing batch 11640 to 11650
# Processing batch 11650 to 11660
# Processing batch 11660 to 11670
# Processing batch 11670 to 11680
# Processing batch 11680 to 11690
# Processing batch 11690 to 11700
# Processing batch 11700 to 11710
# Processing batch 11710 to 11720
# Processing batch 11720 to 11730
# Processing batch 11730 to 11740
# Processing batch 11740 to 11750
# Processing batch 11750 to 11760
# Processing batch 11760 to 11770
# Processing batch 11770 to 11780
# Processing batch 11780 to 11790
# Processing batch 11790 to 11800
# Processing batch 11800 to 11810
# Processing batch 11810 to 11820
# Processing batch 11820 to 11830
# Processing batch 11830 to 11840
# Processing batch 11840 to 11850
# Processing batch 11850 to 11860
# Processing batch 11860 to 11870
# Processing batch 11870 to 11880
# Processing batch 11880 to 11890
# Processing batch 11890 to 11900
# Processing batch 11900 to 11910
# Processing batch 11910 to 11920
# Processing batch 11920 to 11930
# Processing batch 11930 to 11940
# Processing batch 11940 to 11950
# Processing batch 11950 to 11960
# Processing batch 11960 to 11970
# Processing batch 11970 to 11980
# Processing batch 11980 to 11990
# Processing batch 11990 to 12000
# Processing batch 12000 to 12010
# Processing batch 12010 to 12020
# Processing batch 12020 to 12030
# Processing batch 12030 to 12040
# Processing batch 12040 to 12050
# Processing batch 12050 to 12060
# Processing batch 12060 to 12070
# Processing batch 12070 to 12080
# Processing batch 12080 to 12090
# Processing batch 12090 to 12100
# Processing batch 12100 to 12110
# Processing batch 12110 to 12120
# Processing batch 12120 to 12130
# Processing batch 12130 to 12140
# Processing batch 12140 to 12150
# Processing batch 12150 to 12160
# Processing batch 12160 to 12170
# Processing batch 12170 to 12180
# Processing batch 12180 to 12190
# Processing batch 12190 to 12200
# Processing batch 12200 to 12210
# Processing batch 12210 to 12220
# Processing batch 12220 to 12230
# Processing batch 12230 to 12240
# Processing batch 12240 to 12250
# Processing batch 12250 to 12260
# Processing batch 12260 to 12270
# Processing batch 12270 to 12280
# Processing batch 12280 to 12290
# Processing batch 12290 to 12300
# Processing batch 12300 to 12310
# Processing batch 12310 to 12320
# Processing batch 12320 to 12330
# Processing batch 12330 to 12340
# Processing batch 12340 to 12350
# Processing batch 12350 to 12360
# Processing batch 12360 to 12370
# Processing batch 12370 to 12380
# Processing batch 12380 to 12390
# Processing batch 12390 to 12400
# Processing batch 12400 to 12410
# Processing batch 12410 to 12420
# Processing batch 12420 to 12430
# Processing batch 12430 to 12440
# Processing batch 12440 to 12450
# Processing batch 12450 to 12460
# Processing batch 12460 to 12470
# Processing batch 12470 to 12480
# Processing batch 12480 to 12490
# Processing batch 12490 to 12500
# Processing batch 12500 to 12510
# Processing batch 12510 to 12520
# Processing batch 12520 to 12530
# Processing batch 12530 to 12540
# Processing batch 12540 to 12550
# Processing batch 12550 to 12560
# Processing batch 12560 to 12570
# Processing batch 12570 to 12580
# Processing batch 12580 to 12590
# Processing batch 12590 to 12600
# Processing batch 12600 to 12610
# Processing batch 12610 to 12620
# Processing batch 12620 to 12630
# Processing batch 12630 to 12640
# Processing batch 12640 to 12650
# Processing batch 12650 to 12660
# Processing batch 12660 to 12670
# Processing batch 12670 to 12680
# Processing batch 12680 to 12690
# Processing batch 12690 to 12700
# Processing batch 12700 to 12710
# Processing batch 12710 to 12720
# Processing batch 12720 to 12730
# Processing batch 12730 to 12740
# Processing batch 12740 to 12750
# Processing batch 12750 to 12760
# Processing batch 12760 to 12770
# Processing batch 12770 to 12780
# Processing batch 12780 to 12790
# Processing batch 12790 to 12800
# Processing batch 12800 to 12810
# Processing batch 12810 to 12820
# Processing batch 12820 to 12830
# Processing batch 12830 to 12840
# Processing batch 12840 to 12850
# Processing batch 12850 to 12860
# Processing batch 12860 to 12870
# Processing batch 12870 to 12880
# Processing batch 12880 to 12890
# Processing batch 12890 to 12900
# Processing batch 12900 to 12910
# Processing batch 12910 to 12920
# Processing batch 12920 to 12930
# Processing batch 12930 to 12940
# Processing batch 12940 to 12950
# Processing batch 12950 to 12960
# Processing batch 12960 to 12970
# Processing batch 12970 to 12980
# Processing batch 12980 to 12990
# Processing batch 14030 to 14040
# Processing batch 14040 to 14050
# Processing batch 14050 to 14060
# Processing batch 14060 to 14070
# Processing batch 14070 to 14080
# Processing batch 14080 to 14090
# Processing batch 14090 to 14100
# Processing batch 14100 to 14110
# Processing batch 14110 to 14120
# Processing batch 14120 to 14130
# Processing batch 14130 to 14140
# Processing batch 14140 to 14150
# Processing batch 14150 to 14160
# Processing batch 14160 to 14170
# Processing batch 14170 to 14180
# Processing batch 14180 to 14190
# Processing batch 14190 to 14200
# Processing batch 14200 to 14210
# Processing batch 14210 to 14220
# Processing batch 14220 to 14230
# Processing batch 14230 to 14240
# Processing batch 14240 to 14250
# Processing batch 14250 to 14260
# Processing batch 14260 to 14270
# Processing batch 14270 to 14280
# Processing batch 14280 to 14290
# Processing batch 14290 to 14300
# Processing batch 14300 to 14310
# Processing batch 14310 to 14320
# Processing batch 14320 to 14330
# Processing batch 14330 to 14340
# Processing batch 14340 to 14350
# Processing batch 14350 to 14360
# Processing batch 14360 to 14370
# Processing batch 14370 to 14380
# Processing batch 14380 to 14390
# Processing batch 14390 to 14400
# Processing batch 14400 to 14410
# Processing batch 14410 to 14420
# Processing batch 14420 to 14430
# Processing batch 14430 to 14440
# Processing batch 14440 to 14450
# Processing batch 14450 to 14460
# Processing batch 14460 to 14470
# Processing batch 14470 to 14480
# Processing batch 14480 to 14490
# Processing batch 14490 to 14500
# Processing batch 14500 to 14510
# Processing batch 14510 to 14520
# Processing batch 14520 to 14530
# Processing batch 14530 to 14540
# Processing batch 14540 to 14550
# Processing batch 14550 to 14560
# Processing batch 14560 to 14570
# Processing batch 14570 to 14580
# Processing batch 14580 to 14590
# Processing batch 14590 to 14600
# Processing batch 14600 to 14610
# Processing batch 14610 to 14620
# Processing batch 14620 to 14630
# Processing batch 14630 to 14640
# Processing batch 14640 to 14650
# Processing batch 14650 to 14660
# Processing batch 14660 to 14670
# Processing batch 14670 to 14680
# Processing batch 14680 to 14690
# Processing batch 14690 to 14700
# Processing batch 14700 to 14710
# Processing batch 14710 to 14720
# Processing batch 14720 to 14730
# Processing batch 14730 to 14740
# Processing batch 14740 to 14750
# Processing batch 14750 to 14760
# Processing batch 14760 to 14770
# Processing batch 14770 to 14780
# Processing batch 14780 to 14790
# Processing batch 14790 to 14800
# Processing batch 14800 to 14810
# Processing batch 14810 to 14820
# Processing batch 14820 to 14830
# Processing batch 14830 to 14840
# Processing batch 14840 to 14850
# Processing batch 14850 to 14860
# Processing batch 14860 to 14870
# Processing batch 14870 to 14880
# Processing batch 14880 to 14890
# Processing batch 14890 to 14900
# Processing batch 14900 to 14910
# Processing batch 14910 to 14920
# Processing batch 14920 to 14930
# Processing batch 14930 to 14940
# Processing batch 14940 to 14950
# Processing batch 14950 to 14960
# Processing batch 14960 to 14970
# Processing batch 14970 to 14980
# Processing batch 14980 to 14990
# Processing batch 14990 to 15000
# Processing batch 15000 to 15010
# Processing batch 15010 to 15020
# Processing batch 15020 to 15030
# Processing batch 15030 to 15040
# Processing batch 15040 to 15050
# Processing batch 15050 to 15060
# Processing batch 15060 to 15070
# Processing batch 15070 to 15080
# Processing batch 15080 to 15090
# Processing batch 15090 to 15100
# Processing batch 15100 to 15110
# Processing batch 15110 to 15120
# Processing batch 15120 to 15130
# Processing batch 15130 to 15140
# Processing batch 15140 to 15150
# Processing batch 15150 to 15160
# Processing batch 15160 to 15170
# Processing batch 15170 to 15180
# Processing batch 15180 to 15190
# Processing batch 15190 to 15200
# Processing batch 15200 to 15210
# Processing batch 15210 to 15220
# Processing batch 15220 to 15230
# Processing batch 15230 to 15240
# Processing batch 15240 to 15250
# Processing batch 15250 to 15260
# Processing batch 15260 to 15270
# Processing batch 15270 to 15280
# Processing batch 15280 to 15290
# Processing batch 15290 to 15300
# Processing batch 15300 to 15310
# Processing batch 15310 to 15320
# Processing batch 15320 to 15330
# Processing batch 15330 to 15340
# Processing batch 15340 to 15350
# Processing batch 15350 to 15360
# Processing batch 15360 to 15370
# Processing batch 15370 to 15380
# Processing batch 15380 to 15390
# Processing batch 15390 to 15400
# Processing batch 15400 to 15410
# Processing batch 15410 to 15420
# Processing batch 15420 to 15430
# Processing batch 15430 to 15440
# Processing batch 15440 to 15450
# Processing batch 15450 to 15460
# Processing batch 15460 to 15470
# Processing batch 15470 to 15480
# Processing batch 15480 to 15490
# Processing batch 15490 to 15500
# Processing batch 15500 to 15510
# Processing batch 15510 to 15520
# Processing batch 15520 to 15530
# Processing batch 15530 to 15540
# Processing batch 15540 to 15550
# Processing batch 15550 to 15560
# Processing batch 15560 to 15570
# Processing batch 15570 to 15580
# Processing batch 15580 to 15590
# Processing batch 15590 to 15600
# Processing batch 15600 to 15610
# Processing batch 15610 to 15620
# Processing batch 15620 to 15630
# Processing batch 15630 to 15640
# Processing batch 15640 to 15650
# Processing batch 15650 to 15660
# Processing batch 15660 to 15670
# Processing batch 15670 to 15680
# Processing batch 15680 to 15690
# ...
# Processing batch 153600 to 153610
# Processing batch 153610 to 153620
# Processing batch 153620 to 153630
# Processing batch 153630 to 153640
# Processing batch 153640 to 153650
# Processing batch 153650 to 153660
# Processing batch 153660 to 153670
# Processing batch 153670 to 153680
# Processing batch 153680 to 153690
# Processing batch 153690 to 153700
# Processing batch 153700 to 153710
# Processing batch 153710 to 153720
# Processing batch 153720 to 153730
# Processing batch 153730 to 153740
# Processing batch 153740 to 153750
# Processing batch 153750 to 153760
# Processing batch 153760 to 153770
# Processing batch 153770 to 153780
# Processing batch 153780 to 153790
# Processing batch 153790 to 153800
# Processing batch 153800 to 153810
# Processing batch 153810 to 153820
# Processing batch 153820 to 153830
# Processing batch 153830 to 153840
# Processing batch 153840 to 153850
# Processing batch 153850 to 153860
# Processing batch 153860 to 153870
# Processing batch 153870 to 153880
# Processing batch 153880 to 153890
# Processing batch 153890 to 153900
# Processing batch 153900 to 153910
# Processing batch 153910 to 153920
# Processing batch 153920 to 153930
# Processing batch 153930 to 153940
# Processing batch 153940 to 153950
# Processing batch 153950 to 153960
# Processing batch 153960 to 153970
# Processing batch 153970 to 153980
# Processing batch 153980 to 153990
# Processing batch 153990 to 154000
# Processing batch 154000 to 154010
# Processing batch 154010 to 154020
# Processing batch 154020 to 154030
# Processing batch 154030 to 154040
# Processing batch 154040 to 154050
# Processing batch 154050 to 154060
# Processing batch 154060 to 154070
# Processing batch 154070 to 154080
# Processing batch 154080 to 154090
# Processing batch 154090 to 154100
# Processing batch 154100 to 154110
# Processing batch 154110 to 154120
# Processing batch 154120 to 154130
# Processing batch 154130 to 154140
# Processing batch 154140 to 154150
# Processing batch 154150 to 154160
# Processing batch 154160 to 154170
# Processing batch 154170 to 154180
# Processing batch 154180 to 154190
# Processing batch 154190 to 154200
# Processing batch 154200 to 154210
# Processing batch 154210 to 154220
# Processing batch 154220 to 154230
# Processing batch 154230 to 154240
# Processing batch 154240 to 154250
# Processing batch 154250 to 154260
# Processing batch 154260 to 154270
# Processing batch 154270 to 154280
# Processing batch 154280 to 154290
# Processing batch 154290 to 154300
# Processing batch 154300 to 154310
# Processing batch 154310 to 154320
# Processing batch 154320 to 154330
# Processing batch 154330 to 154340
# Processing batch 154340 to 154350
# Processing batch 154350 to 154360
# Processing batch 154360 to 154370
# Processing batch 154370 to 154380
# Processing batch 154380 to 154390
# Processing batch 154390 to 154400
# Processing batch 154400 to 154410
# Processing batch 154410 to 154420
# Processing batch 154420 to 154430
# Processing batch 154430 to 154440
# Processing batch 154440 to 154450
# Processing batch 154450 to 154460
# Processing batch 154460 to 154470
# Processing batch 154470 to 154480
# Processing batch 154480 to 154490
# Processing batch 154490 to 154500
# Processing batch 154500 to 154510
# Processing batch 154510 to 154520
# Processing batch 154520 to 154530
# Processing batch 154530 to 154540
# Processing batch 154540 to 154550
# Processing batch 154550 to 154560
# Processing batch 154560 to 154570
# Processing batch 154570 to 154580
# Processing batch 154580 to 154590
# Processing batch 154590 to 154600
# Processing batch 154600 to 154610
# Processing batch 154610 to 154620
# Processing batch 154620 to 154630
# Processing batch 154630 to 154640
# Processing batch 154640 to 154650
# Processing batch 154650 to 154660
# Processing batch 154660 to 154670
# Processing batch 154670 to 154680
# Processing batch 154680 to 154690
# Processing batch 154690 to 154700
# Processing batch 154700 to 154710
# Processing batch 154710 to 154720
# Processing batch 154720 to 154730
# Processing batch 154730 to 154740
# Processing batch 154740 to 154750
# Processing batch 154750 to 154760
# Processing batch 154760 to 154770
# Processing batch 154770 to 154780
# Processing batch 154780 to 154790
# Processing batch 154790 to 154800
# Processing batch 154800 to 154810
# Processing batch 154810 to 154820
# Processing batch 154820 to 154830
# Processing batch 154830 to 154840
# Processing batch 154840 to 154850
# Processing batch 154850 to 154860
# Processing batch 154860 to 154870
# Processing batch 154870 to 154880
# Processing batch 154880 to 154890
# Processing batch 154890 to 154900
# Processing batch 154900 to 154910
# Processing batch 154910 to 154920
# Processing batch 154920 to 154930
# Processing batch 154930 to 154940
# Processing batch 154940 to 154950
# Processing batch 154950 to 154960
# Processing batch 154960 to 154970
# Processing batch 154970 to 154980
# Processing batch 154980 to 154990
# Processing batch 154990 to 155000
# Processing batch 155000 to 155010
# Processing batch 155010 to 155020
# Processing batch 155020 to 155030
# Processing batch 156060 to 156070
# Processing batch 156070 to 156080
# Processing batch 156080 to 156090
# Processing batch 156090 to 156100
# Processing batch 156100 to 156110
# Processing batch 156110 to 156120
# Processing batch 156120 to 156130
# Processing batch 156130 to 156140
# Processing batch 156140 to 156150
# Processing batch 156150 to 156160
# Processing batch 156160 to 156170
# Processing batch 156170 to 156180
# Processing batch 156180 to 156190
# Processing batch 156190 to 156200
# Processing batch 156200 to 156210
# Processing batch 156210 to 156220
# Processing batch 156220 to 156230
# Processing batch 156230 to 156240
# Processing batch 156240 to 156250
# Processing batch 156250 to 156260
# Processing batch 156260 to 156270
# Processing batch 156270 to 156280
# Processing batch 156280 to 156290
# Processing batch 156290 to 156300
# Processing batch 156300 to 156310
# Processing batch 156310 to 156320
# Processing batch 156320 to 156330
# Processing batch 156330 to 156340
# Processing batch 156340 to 156350
# Processing batch 156350 to 156360
# Processing batch 156360 to 156370
# Processing batch 156370 to 156380
# Processing batch 156380 to 156390
# Processing batch 156390 to 156400
# Processing batch 156400 to 156410
# Processing batch 156410 to 156420
# Processing batch 156420 to 156430
# Processing batch 156430 to 156440
# Processing batch 156440 to 156450
# Processing batch 156450 to 156460
# Processing batch 156460 to 156470
# Processing batch 156470 to 156480
# Processing batch 156480 to 156490
# Processing batch 156490 to 156500
# Processing batch 156500 to 156510
# Processing batch 156510 to 156520
# Processing batch 156520 to 156530
# Processing batch 156530 to 156540
# Processing batch 156540 to 156550
# Processing batch 156550 to 156560
# Processing batch 156560 to 156570
# Processing batch 156570 to 156580
# Processing batch 156580 to 156590
# Processing batch 156590 to 156600
# Processing batch 156600 to 156610
# Processing batch 156610 to 156620
# Processing batch 156620 to 156630
# Processing batch 156630 to 156640
# Processing batch 156640 to 156650
# Processing batch 156650 to 156660
# Processing batch 156660 to 156670
# Processing batch 156670 to 156680
# Processing batch 156680 to 156690
# Processing batch 156690 to 156700
# Processing batch 156700 to 156710
# Processing batch 156710 to 156720
# Processing batch 156720 to 156730
# Processing batch 156730 to 156740
# Processing batch 156740 to 156750
# Processing batch 156750 to 156760
# Processing batch 156760 to 156770
# Processing batch 156770 to 156780
# Processing batch 156780 to 156790
# Processing batch 156790 to 156800
# Processing batch 156800 to 156810
# Processing batch 156810 to 156820
# Processing batch 156820 to 156830
# Processing batch 156830 to 156840
# Processing batch 156840 to 156850
# Processing batch 156850 to 156860
# Processing batch 156860 to 156870
# Processing batch 156870 to 156880
# Processing batch 156880 to 156890
# Processing batch 156890 to 156900
# Processing batch 156900 to 156910
# Processing batch 156910 to 156920
# Processing batch 156920 to 156930
# Processing batch 156930 to 156940
# Processing batch 156940 to 156950
# Processing batch 156950 to 156960
# Processing batch 156960 to 156970
# Processing batch 156970 to 156980
# Processing batch 156980 to 156990
# Processing batch 156990 to 157000
# Processing batch 157000 to 157010
# Processing batch 157010 to 157020
# Processing batch 157020 to 157030
# Processing batch 157030 to 157040
# Processing batch 157040 to 157050
# Processing batch 157050 to 157060
# Processing batch 157060 to 157070
# Processing batch 157070 to 157080
# Processing batch 157080 to 157090
# Processing batch 158120 to 158130
# Processing batch 158130 to 158140
# Processing batch 158140 to 158150
# Processing batch 158150 to 158160
# Processing batch 158160 to 158170
# Processing batch 158170 to 158180
# Processing batch 158180 to 158190
# Processing batch 158190 to 158200
# Processing batch 158200 to 158210
# Processing batch 158210 to 158220
# Processing batch 158220 to 158230
# Processing batch 158230 to 158240
# Processing batch 158240 to 158250
# Processing batch 158250 to 158260
# Processing batch 158260 to 158270
# Processing batch 158270 to 158280
# Processing batch 158280 to 158290
# Processing batch 158290 to 158300

# %%
'''Validate the track level data pull from cell above'''

#de_dup_tracks.to_csv('track_data.csv')
#de_dup_tracks[(de_dup_tracks['strMusicVid'] != 'N/A') & (de_dup_tracks['strMusicVid'].notna())].head(5)
de_dup_tracks.rename(columns={'Track_MusicBrainzID_y': 'Track_MusicBrainzID'}, inplace=True)
len(de_dup_tracks)


'''Remove any duplicates from both dataframes'''

# Get all column names except the index
columns_to_check = [col for col in df_exploded.columns if col != 'Unnamed:']

# Drop duplicates based on all columns except the excluded one
de_dup_tracks = df_exploded.drop_duplicates(subset=columns_to_check)

# %% [markdown]
# Clean up the Song level dataset

# %%
#Fix the null values to be consistent. Instead of 'N/A', it can just be None
de_dup_tracks['Track_MusicVidViews'] = de_dup_tracks['Track_MusicVidViews'].apply(lambda x: None if x == "N/A" else x)
de_dup_tracks['Track_MusicVidLikes'] = de_dup_tracks['Track_MusicVidLikes'].apply(lambda x: None if x == "N/A" else x)
de_dup_tracks['Track_MusicVidDislikes'] = de_dup_tracks['Track_MusicVidDislikes'].apply(lambda x: None if x == "N/A" else x)
de_dup_tracks['Track_MusicVidComments'] = de_dup_tracks['Track_MusicVidComments'].apply(lambda x: None if x == "N/A" else x)
de_dup_tracks['Track_totalListeners'] = de_dup_tracks['Track_totalListeners'].apply(lambda x: None if x == "N/A" else x)
de_dup_tracks['Track_TotalPlays'] = de_dup_tracks['Track_TotalPlays'].apply(lambda x: None if x == "N/A" else x)

print(len(de_dup_tracks))

#de_dup_tracks.to_csv('Final_Track_DB_V1.csv')
# Out:
# 158293

# %% [markdown]
# Below, we try adding another predictor variable.
#
# We will check to see if the song has appeared on the Billboard Hot 100 charts.
#
# We will test our model's ability to predict both the popularity score that is within the original dataset, as well as the below created column: artist_and_song_in_hot100
#
# Source of hot 100 data: https://github.com/HipsterVizNinja/random-data/tree/main/Music/hot-100

# %%
'''Add column for Billboard Hot 100'''

file_path = 'Hot 100.csv'
hot100 = pd.read_csv(file_path)

# %%
'''To add additional fields, we can use the code below to upload our previously saved file and add onto it. 

Commenting it out for readability. This does not need to be used if running the code in order. It is the same as the first cells ran in the beginning of this program.'''

# de_dup_tracks = pd.read_csv('Final_Track_DB_1.csv', encoding="utf-8")

# #clean table: if track name contains "(feat. %)" or "(with %)" then remove that text from the song title 
# #using regular expressions and making sure its not case sensitive
# de_dup_tracks['track_name'] = de_dup_tracks['track_name'].replace(r'(?i)\s*\(feat\.?[^)]*\)','', regex=True)
# de_dup_tracks['track_name'] = de_dup_tracks['track_name'].replace(r'(?i)\s*\(with\.?[^)]*\)','', regex=True)

# #fix text issue i am seeing
# def fix_text(text):
#     if isinstance(text, str):
#         try:
#             # Try cp1252 encoding with replacing problematic bytes,
#             # then decoding as utf-8 while replacing problematic bytes
#             return text.encode('cp1252', errors='replace').decode('utf-8', errors='replace')
#         except UnicodeDecodeError:
#             # Fallback: ignore decode errors if the above fails
#             return text.encode('cp1252', errors='replace').decode('utf-8', errors='ignore')
#     return text

# import unicodedata

# #to match hot100, it doesnt have the spanish alphabet characters. the code below should normalize the song titles to match the database
# def remove_accents(text):
#     text = str(text) #some songs are numbers (:
#     # Normalize the text to decompose accented characters
#     normalized_text = unicodedata.normalize('NFKD', text)
#     # Remove the combining characters (accents) by filtering them out
#     return "".join(c for c in normalized_text if not unicodedata.combining(c))

# de_dup_tracks['track_name'] = de_dup_tracks['track_name'].apply(fix_text)
# de_dup_tracks['artists'] = de_dup_tracks['artists'].apply(fix_text)

# de_dup_tracks['track_name'] = de_dup_tracks['track_name'].str.replace("’", "'", regex=False)
# de_dup_tracks['artists'] = de_dup_tracks['artists'].str.replace("’", "'", regex=False)

# de_dup_tracks['track_name'] = de_dup_tracks['track_name'].apply(remove_accents)
# de_dup_tracks['artists'] = de_dup_tracks['artists'].apply(remove_accents)
# Out:
# C:\Users\Destiny\AppData\Local\Temp\ipykernel_14872\930603557.py:1: DtypeWarning: Columns (10,45,49,50,51,52,53,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   de_dup_tracks = pd.read_csv('Final_Track_DB_1.csv', encoding="utf-8")

# %%
'''The column for artists in the hot100 dataset is delimited with many different methods: "&", ",", "featuring", "feat.", "with", etc.  
so we need to split up the hot100 dataset to be at a song/artist level like our current dataset. However, sometimes one of these 
characters is valid in the name like "Tyler, The Creator". So, we can check if the song exists since we know our original dataset is
delimited with ";" we can check if the song exists in the billboard hot 100, and if it does, we can check if the artist in our original
dataframe is contained within the performers column of the billboard data '''

import string

#Function to make text comparable
def normalize(text):
    if pd.isna(text):
        return ""
    return str(text).strip().lower()

#Use function to level out our comparison
de_dup_tracks['track_name'] = de_dup_tracks['track_name'].apply(normalize)
de_dup_tracks['artists']    = de_dup_tracks['artists'].apply(normalize)
hot100['song'] = hot100['song'].apply(normalize)
hot100['performer'] = hot100['performer'].apply(normalize)

#Validate it is working properly:
#print("hot 100:")
#print(hot100[hot100['song'].str.contains("i don't wanna live forever")].head(5))

#print("df before adding new col:")
#print(de_dup_tracks[(de_dup_tracks['artists'].apply(normalize).str.contains('taylor swift'))])
#print(de_dup_tracks[de_dup_tracks['track_name'].str.contains("i don't wanna live forever")])

#Check if song exists in Hot100
de_dup_tracks['song_exists_in_hot100'] = de_dup_tracks['track_name'].isin(hot100['song'])

#Validate what song exists in hot 100 shows
#print("df after adding new col")
#print(de_dup_tracks[(de_dup_tracks['artists'].apply(normalize).str.contains('taylor swift'))])
#print(de_dup_tracks[de_dup_tracks['track_name'].str.contains("i don't wanna live forever")])

# Group all performers for a song and joins them with a space, so everyone is one string of text.
hot100_grouped = hot100.groupby('song')['performer'].apply(lambda x: ' '.join(x)).reset_index()

# Create a lookup dictionary from the grouped DataFrame
hot100_lookup = hot100_grouped.set_index('song')['performer'].to_dict()

#check if the artist form our original dataframe is within the hot100
def robust_check_artist(artist, performer):
    # Remove punctuation and whitespace to compare
    translator = str.maketrans('', '', string.punctuation)
    artist_clean = artist.translate(translator).replace(" ", "")
    performer_clean = performer.translate(translator).replace(" ", "")
    return artist_clean in performer_clean

def check_artist_for_song(row):
    song = row['track_name']
    artist = row['artists']
    performer = hot100_lookup.get(song, "")
    return robust_check_artist(artist, performer)

#Apply the check with new column
de_dup_tracks['artist_and_song_in_hot100'] = de_dup_tracks.apply(check_artist_for_song, axis=1)

#Check if there are mismatches between the song match and song+artist match (this is expected, but can be manually reviewed to ensure the values make sense)
debug_mismatch = pd.merge(
    de_dup_tracks[ (de_dup_tracks['song_exists_in_hot100']) & (~de_dup_tracks['artist_and_song_in_hot100']) ],
    hot100_grouped,
    left_on='track_name',
    right_on='song',
    how='left',
    suffixes=('_df1', '_hot100')
)

debug_mismatch = debug_mismatch[[
    'track_name',     # normalized song from de_dup_tracks
    'artists',        # normalized artist from de_dup_tracks
    'song_exists_in_hot100',
    'artist_and_song_in_hot100',
    'song',           # normalized song from hot100_grouped
    'performer'       # aggregated performer(s) from hot100
]]

# %%
'''Validate the new flags created for hot 100

which songs are mismatched between the two methods and are they valid?'''


print("Length of mismatch df: ",len(debug_mismatch))
print("how many songs/artists ARE in the hot 100: ", len(de_dup_tracks[de_dup_tracks['artist_and_song_in_hot100']==True]))

#Manually validate specific examples for high popularity artists: 
# sorted_df = de_dup_tracks[
#     (de_dup_tracks['artists'] == 'bad bunny') & 
#     (de_dup_tracks['artist_and_song_in_hot100'] != True)
# ].sort_values(by='popularity', ascending=False)

#Validate that any songs showing as a mismatch are not an error. (we would expect high popularity to be more likely to be in the hot 100)
sorted_df = de_dup_tracks[
    (de_dup_tracks['song_exists_in_hot100'] == True ) &
    (de_dup_tracks['artist_and_song_in_hot100'] != True)
].sort_values(by='popularity', ascending=False)

sorted_df.head(10)
# Out:
# Length of mismatch df:  16711
# how many songs/artists ARE in the hot 100:  9650
#           Row                track_id       artists  \
# 113206  81024  0mBP9X2gPCuapvpZ7TGDk3           bts
# 25985   20017  0mBP9X2gPCuapvpZ7TGDk3           bts
# 48519   34014  1Fid2jjqsHViMX6xNH70hE       seafret
# 114663  81857  1R0a2iXumgCiFb7HEZ7gUE  taylor swift
# 120152  86000  7EkWXAI1wn8Ii883ecd9xr    surf curse
# 71710   51503  4woTEX1wYOTGDqNXuavlRC      dina rae
# 89712   65056  0RDqNCRBGrSegk16Avfzuq         twice
# 80376   57054  7EkWXAI1wn8Ii883ecd9xr    surf curse
# 79098   56051  7EkWXAI1wn8Ii883ecd9xr    surf curse
# 42534   30365  1bgKMxPQU7JIZEhNsM1vFs  zara larsson
#
#                                      album_name      track_name  Unnamed: 5  \
# 113206  Left and Right (Feat. Jung Kook of BTS)  left and right         NaN
# 25985   Left and Right (Feat. Jung Kook of BTS)  left and right         NaN
# 48519      Tell Me It's Real (Expanded Edition)        atlantis         NaN
# 114663                               reputation  don't blame me         NaN
# 120152                                   Freaks          freaks         NaN
# 71710                           The Eminem Show        superman         NaN
# 89712                               BETWEEN 1&2  talk that talk         NaN
# 80376                                    Freaks          freaks         NaN
# 79098                                    Freaks          freaks         NaN
# 42534                Words (feat. Zara Larsson)           words         NaN
#
#         Unnamed: 6                                             concat  \
# 113206         NaN  810240mBP9X2gPCuapvpZ7TGDk3BTSLeft and Right (...
# 25985          NaN  200170mBP9X2gPCuapvpZ7TGDk3BTSLeft and Right (...
# 48519          NaN  340141Fid2jjqsHViMX6xNH70hESeafretTell Me It's...
# 114663         NaN  818571R0a2iXumgCiFb7HEZ7gUETaylor Swiftreputat...
# 120152         NaN  860007EkWXAI1wn8Ii883ecd9xrSurf CurseFreaksFreaks
# 71710          NaN  515034woTEX1wYOTGDqNXuavlRCDina RaeThe Eminem ...
# 89712          NaN  650560RDqNCRBGrSegk16AvfzuqTWICEBETWEEN 1&2Tal...
# 80376          NaN  570547EkWXAI1wn8Ii883ecd9xrSurf CurseFreaksFreaks
# 79098          NaN  560517EkWXAI1wn8Ii883ecd9xrSurf CurseFreaksFreaks
# 42534          NaN  303651bgKMxPQU7JIZEhNsM1vFsZara LarssonWords (...
#
#         popularity  duration_ms  ... Track_MusicVidViews  Track_MusicVidLikes  \
# 113206          92       154486  ...                   0                  NaN
# 25985           92       154486  ...                   0                  0.0
# 48519           90       229173  ...                   0                  0.0
# 114663          88       236413  ...                   0                  NaN
# 120152          86       147062  ...                   0                  0.0
# 71710           86       350320  ...                   0                    0
# 89712           86       177466  ...                   0                  NaN
# 80376           86       147062  ...                   0                    0
# 79098           86       147062  ...                   0                    0
# 42534           85       142677  ...                   0                  0.0
#
#         Track_MusicVidDislikes  Track_MusicVidComments  Track_totalListeners  \
# 113206                     NaN                     NaN                   NaN
# 25985                      NaN                     NaN                   NaN
# 48519                      0.0                     0.0               56922.0
# 114663                     NaN                     NaN                   NaN
# 120152                     0.0                     0.0                   0.0
# 71710                      NaN                     NaN                   NaN
# 89712                      NaN                     NaN                   NaN
# 80376                        0                       0                     0
# 79098                        0                       0                     0
# 42534                      NaN                     NaN                   NaN
#
#         Track_TotalPlays                   Track_MusicBrainzID  Hot100  \
# 113206               NaN                                   NaN   False
# 25985                NaN                                   NaN   False
# 48519           373887.0  f6471913-5792-4046-946c-0f4447a1c543   False
# 114663               NaN                                   NaN   False
# 120152               0.0  63180294-3515-45e8-b418-72d04597ca35   False
# 71710                NaN                                   NaN   False
# 89712                NaN                                   NaN   False
# 80376                  0  63180294-3515-45e8-b418-72d04597ca35   False
# 79098                  0  63180294-3515-45e8-b418-72d04597ca35   False
# 42534                NaN                                   NaN   False
#
#         song_exists_in_hot100  artist_and_song_in_hot100
# 113206                   True                      False
# 25985                    True                      False
# 48519                    True                      False
# 114663                   True                      False
# 120152                   True                      False
# 71710                    True                      False
# 89712                    True                      False
# 80376                    True                      False
# 79098                    True                      False
# 42534                    True                      False
#
# [10 rows x 59 columns]

# %%
de_dup_tracks.to_csv('Final_Track_DB_V3.csv')
